# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Valence

# %%
matplotlib.rc('xtick', labelsize = 20) 
matplotlib.rc('ytick', labelsize = 25)
labels = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19',\
          's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
all_channel = [45.0, 67.5, 67.5, 52.5, 62.5, 75.0, 60.0, 52.5, 75.0, 62.5, 57.49, 55.0, 60.0, 62.5, 67.5, \
               65.0, 50.0, 77.5, 65.0, 72.5, 15.0, 60.0, 72.5, 55, 75.0, 50.0, 75.0, 62.5, 75.0, 60.0, 62.5, 62.5]
# valence
opt_channel = [67.5, 70.0, 87.5, 60.0, 72.5, 77.5, 75.0, 67.5, 85.0, 67.5, 70.0, 75.0, 70.0, 72.5, 72.5, 72.5, 67.5,\
               92.5, 72.5, 85.0, 52.5, 72.5, 80.0, 67.5, 80.0, 70.0, 77.5, 77.5, 77.5, 67.5, 67.5, 65.0]
print(np.mean(np.array(all_channel)), np.mean(np.array(opt_channel)))
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize =(20, 10))
rects2 = ax.bar(x - width/2, all_channel, width, label = 'all channels')
rects1 = ax.bar(x + width/2, opt_channel, width, label = 'selected channels')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy', fontsize = 30)
ax.set_xlabel('Subjects', fontsize = 30)
ax.set_title('High/Low Valence', fontsize=30)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=85, fontsize=25)
ax.legend(fontsize=18, loc='upper right')
ax.autoscale(tight=True, axis = "x")
plt.ylim([0, 100])
plt.savefig("sub_dep_valence.pdf")
plt.show()
# Out:
# 61.7965625 72.96875

# %% [markdown]
# # Arousal

# %%
matplotlib.rc('xtick', labelsize = 20) 
matplotlib.rc('ytick', labelsize = 25)
#fig = plt.subplots(figsize =(12, 8))
labels = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19',\
          's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
all_channel = [60.0, 55, 70.0, 55, 45.0, 50.0, 47.5, 60.0, 60.0, 50.0, 60.0, 82.5, 75.0, 65.0, 60.0, 67.5, 70.0,\
               67.5, 60.0, 75.0, 77.5, 40.0, 70.0, 80.0, 75.0, 57.5, 70.0, 40.0, 72.5, 67.5, 57.5, 57.5]
# valence
opt_channel = [80.0, 62.5, 80.0, 60.0, 52.5, 55, 72.5, 65.0, 65.0, 57.5, 62.5, 85.0, 85.0, 67.5, 72.5, 77.5, 77.5,\
               70.0, 67.5, 80.0, 82.5, 67.5, 82.5, 82.5, 75.0, 65.0, 72.5, 60.0, 87.5, 67.5, 77.5, 75.0]
print(np.mean(np.array(all_channel)), np.mean(np.array(opt_channel)))
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize =(20, 10))
rects1 = ax.bar(x - width/2, all_channel, width, label = 'all channels')
rects2 = ax.bar(x + width/2, opt_channel, width, label = 'selected channels')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy', fontsize = 30)
ax.set_xlabel('Subjects', fontsize = 30)
ax.set_title('High/Low Arousal', fontsize = 30)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=85, fontsize=25)
ax.legend(fontsize=18, loc='upper right')
ax.autoscale(tight=True, axis = "x")
#fig.tight_layout(pad=1.08, h_pad=None, w_pad=0.1, rect=None)
plt.ylim([0, 100])
plt.savefig("sub_dep_arousal.pdf")
plt.show()
# Out:
# 62.5 71.5625

# %% [markdown]
# # Four Class

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
#fig = plt.subplots(figsize =(12, 8))
labels = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19',\
          's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
all_channel = [27.5, 45.0, 40.0, 42.5, 10.0, 37.5, 30.0, 32.5, 40.0, 30.0, 17.5, 47.5, 32.5, 42.5, 47.5, 37.5,\
               27.5, 32.5, 22.5, 52.5, 37.5, 22.5, 42.5, 30.0, 52.5, 42.5, 60.0, 17.5, 45.0, 17.5, 45.0, 25.0]
# valence
opt_channel = [57.5, 52.5, 67.5, 47.5, 25.0, 60.0, 45.0, 42.5, 52.5, 45.0, 22.5, 57.5, 52.5, 52.5, 52.5, 52.5,\
               50.0, 60.0, 45.0, 62.5, 47.5, 45.0, 60.0, 55, 55, 55, 65.0, 47.5, 67.5, 50.0, 55, 37.5]
print(np.mean(np.array(all_channel)), np.mean(np.array(opt_channel)))
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize =(20, 10))
rects1 = ax.bar(x - width/2, all_channel, width, label = 'all channels')
rects2 = ax.bar(x + width/2, opt_channel, width, label = 'selected channels')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy', fontsize = 30)
ax.set_xlabel('Subjects', fontsize= 30)
ax.set_title('HVHA/HVLA/LVLA/LVHA', fontsize=30)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=85, fontsize=25)
ax.legend(fontsize=18, loc='upper right')
ax.autoscale(tight=True, axis = "x")
plt.ylim([0, 80])
plt.savefig("sub_dep_four.pdf")
plt.show()
# Out:
# 35.390625 51.328125

# %%
result = [[95.0  ,  10.0  ,  933  ,  95 ],
[97.5  ,  96.7  , 100  ,  98 ],
[100  ,  10.0  , 100  , 100 ],
[80.0  ,  65.0  ,  75  ,  667 ],
[95.0  ,  95.0  ,  967  ,  947 ],
[82.5  ,  96.7  ,  85  ,  894 ],
[92.5  ,  96.7  ,  942  ,  946 ],
[95.0  ,  10.0  ,  942  ,  966 ],
[92.5  ,  90.0 ,  867  ,  88 ],
[97.5  ,  95.0  , 100  ,  967 ],
[80.0  ,  88.3  ,  842  ,  842 ],
[97.5  ,  95.0  , 100  ,  967 ],
[85.0  ,  70.0  ,  85  ,  733 ],
[90.0  ,  80.0  , 100  ,  867 ],
[92.5  ,  95.0  ,  933  ,  927 ],
[87.5  ,  70.0  ,  8  ,  733 ],
[82.5  ,  90.0  ,  783  ,  827 ],
[97.5  ,  96.7  , 100  ,  98 ],
[95.0  ,  95.0  ,  967  ,  947 ],
[87.5  ,  95.0  ,  867  ,  887 ],
[90.0  ,  95.0  ,  9  ,  907 ],
[90.0  ,  70.0  ,  8  ,  733 ],
[90.0  ,  96.7  ,  9  ,  927 ],
[80.0  ,  75.0  ,  717  ,  713 ],
[97.0  ,  95.0  , 100  ,  967 ],
[90.0   ,  95.0  ,  908  ,  912 ],
[90.0   ,  96.7  ,  925  ,  937 ],
[92.5  ,  91.7  ,  975  ,  932 ],
[100  ,  10.0  , 100  , 100 ],
[85.0   ,  90.0 ,  9  ,  88 ],
[97.5  ,  100  ,  975  ,  986 ],
[87.5  ,  75.0  ,  9  ,  8]]

# %%
np.mean(result, axis = 0)
# Out:
# array([ 91.     ,  79.06875, 457.5    , 681.4375 ])

# %%
np.std(result, axis = 0)
# Out:
# array([  5.875     ,  27.81151333, 422.3990264 , 354.38625974])
