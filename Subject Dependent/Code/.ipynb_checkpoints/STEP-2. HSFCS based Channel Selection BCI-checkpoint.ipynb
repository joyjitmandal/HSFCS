# %%
# !pip install skfeature-chappers

# %%
import pickle, copy, warnings, os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
warnings.filterwarnings("ignore")
from skfeature.utility.construct_W import construct_W
from scipy.sparse import diags

# %% [markdown]
# # Fisher Score

# %%
def fisher_score(X, y):
    """
    This function implements the fisher score feature selection, steps are as follows:
    1. Construct the affinity matrix W in fisher score way
    2. For the r-th feature, we define fr = X(:,r), D = diag(W*ones), ones = [1,...,1]', L = D - W
    3. Let fr_hat = fr - (fr'*D*ones)*ones/(ones'*D*ones)
    4. Fisher score for the r-th feature is score = (fr_hat'*D*fr_hat)/(fr_hat'*L*fr_hat)-1
    Input
    -----
    X: {numpy array}, shape (n_samples, n_features)
        input data
    y: {numpy array}, shape (n_samples,)
        input class labels
    Output
    ------
    score: {numpy array}, shape (n_features,)
        fisher score for each feature
    Reference
    ---------
    He, Xiaofei et al. "Laplacian Score for Feature Selection." NIPS 2005.
    Duda, Richard et al. "Pattern classification." John Wiley & Sons, 2012.
    """
    # Construct weight matrix W in a fisherScore way
    kwargs = {"neighbor_mode": "supervised", "fisher_score": True, 'y': y}
    W = construct_W(X, **kwargs)

    # build the diagonal D matrix from affinity matrix W
    D = np.array(W.sum(axis=1))
    L = W
    tmp = np.dot(np.transpose(D), X)
    D = diags(np.transpose(D), [0])
    Xt = np.transpose(X)
    t1 = np.transpose(np.dot(Xt, D.todense()))
    t2 = np.transpose(np.dot(Xt, L.todense()))
    # compute the numerator of Lr
    D_prime = np.sum(np.multiply(t1, X), 0) - np.multiply(tmp, tmp)/D.sum()
    # compute the denominator of Lr
    L_prime = np.sum(np.multiply(t2, X), 0) - np.multiply(tmp, tmp)/D.sum()
    # avoid the denominator of Lr to be 0
    D_prime[D_prime < 1e-12] = 10000
    lap_score = 1 - np.array(np.multiply(L_prime, 1/D_prime))[0, :]

    # compute fisher score from laplacian score, where fisher_score = 1/lap_score - 1
    score = 1.0/lap_score - 1
    return np.transpose(score)

# %%
def get_fisher_score(subject_name, em_labels):
    data_theta = pd.read_csv(band_wise_data_path + subject_name + '_theta.csv')
    data_alpha = pd.read_csv(band_wise_data_path + subject_name + '_alpha.csv')
    data_beta = pd.read_csv(band_wise_data_path + subject_name + '_beta.csv')
    data_gamma = pd.read_csv(band_wise_data_path + subject_name + '_gamma.csv')
    
    X_theta, X_alpha = np.array(data_theta), np.array(data_alpha)
    X_beta, X_gamma = np.array(data_beta), np.array(data_gamma)
    y = np.array(em_labels)
    # apply scalling of the given data
    scaler = MinMaxScaler()
    scaler.fit(X_theta)
    X_theta = scaler.transform(X_theta)
    scaler.fit(X_alpha)
    X_alpha = scaler.transform(X_alpha)
    scaler.fit(X_beta)
    X_beta = scaler.transform(X_beta)
    scaler.fit(X_gamma)
    X_gamma = scaler.transform(X_gamma)
    
    fscore_theta, fscore_alpha = fisher_score(X_theta, y), fisher_score(X_alpha, y)
    fscore_beta, fscore_gamma = fisher_score(X_beta, y), fisher_score(X_gamma, y)
    
    # Total Avearge F-Score (Theta, Alpha, Beta, Gamma)
    final_f_score = (fscore_theta + fscore_alpha + fscore_beta + fscore_gamma)/4
    fvalues = pd.Series(final_f_score)
    fvalues.index = eeg_channels
    fvalues.sort_values(ascending = False)
    fvalues.to_csv('fscore_final.csv')
    # for visualization run the below code
    # fvalues.sort_values(ascending = False).plot.bar(figsize=(10,8))
    df = fvalues.sort_values(ascending = False)
    da = pd.DataFrame(df)
    da.to_csv('channel_rank.csv')
    cr = pd.read_csv('channel_rank.csv')
    sort_channel_name = list(cr['Unnamed: 0'])
    os.remove('channel_rank.csv') # delete the csv file
    return sort_channel_name

# %%
def emotion_label(labels, class_label):
    em_labels = []
    if(class_label == 'valence'):
        for i in range(0, labels.shape[0]):
            if (labels[i][0]>5): # high valence
                em_labels.append(1)
            else: # low valence
                em_labels.append(0)
        return em_labels
    elif(class_label == 'arousal'):
        for i in range(0, labels.shape[0]):
            if (labels[i][1]>5): # high arousal
                em_labels.append(1)
            else: # low arousal
                em_labels.append(0)
        return em_labels
    elif(class_label == 'all'):
        for i in range(0, labels.shape[0]):
            if (labels[i][0]>5): # high valence
                if(labels[i][1]>5): # high arousal
                    em_labels.append(1) # HVHA
                else:
                    em_labels.append(0) # HVLA
            else: # low valence
                if(labels[i][1]>5): # high arousal
                    em_labels.append(2) # LVHA
                else: # low arousal
                    em_labels.append(3) # LVLA
        return em_labels

# %% [markdown]
# # Classification

# %%
#Loading the dataset
def svmclassifier(channel_name, data):
    channel_names = []
    for i in range(0, len(channel_name)):
        draft = channel_name[i]
        channel_names.append(draft + "_alpha")
        channel_names.append(draft + "_beta")
        channel_names.append(draft + "_gamma")
        channel_names.append(draft + "_theta")
    x, y = data[channel_names], np.array(em_labels)
    # Implementing cross validation
    k = 40
    kf = KFold(n_splits = k, shuffle = False)
    acc_score = []
    for train_index , test_index in kf.split(x):
        x_train, x_test = x.iloc[train_index,:],x.iloc[test_index,:]
        y_train, y_test = y[train_index] , y[test_index]
        model = svm.SVC(kernel = 'poly')
        model.fit(x_train, y_train)
        pred_values = model.predict(x_test)
        #pred_values = model.predict(x_test)
        acc = accuracy_score(pred_values , y_test)
        acc_score.append(acc)
    avg_acc_score = sum(acc_score)/k
    return avg_acc_score

# %%
def growing_phase(channel_name):
    cn = channel_name[0]
    acc = svmclassifier([cn], data.copy())
    cn_list = []
    cn_list.append(cn)
    sort_cn = []
    for i in range(1, len(channel_name)):
        cur_cn = channel_name[i]
        cn_list.append(cur_cn)
        cur_acc = svmclassifier(cn_list, data.copy())
        if(cur_acc<acc):
            cn_list.remove(cur_cn)
        else:
            acc = cur_acc
    print('Accuracy in Growing Phase: ', acc)
    print('No of selected channels in Growing Phase: ', len(cn_list))
    print('Channels selected in Growing Phase: ', cn_list)
    return cn_list

# %% [markdown]
# # Main Drive Code

# %%
subject_names = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 
                 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21',
                 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
eeg_channels = np.array(['Fp1', 'AF3', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 
                         'P7', 'PO3', 'O1', 'Oz', 'Pz', 'Fp2', 'AF4', 'Fz', 'F4', 'F8', 'FC6', 
                         'FC2', 'Cz', 'C4', 'T8', 'CP6', 'CP2', 'P4', 'P8', 'PO4', 'O2'])
class_labels = ['valence', 'arousal', 'all']
# deap dataset path
deap_dataset_path = '/Users/shyammarjit/Desktop/Brain Computer Interface/Deap Dataset/'
# put the path location of datfiles folder s.t. subject wise folder should contain datafiles
datafiles_path = '/Users/shyammarjit/Desktop/Brain Computer Interface/Hybrid Sequential Forward channel selection (HSFCS)/Subject Dependent/datafiles/'

# %%
for subject_name in subject_names[0:32]:
    print("\n")
    print("="*90)
    print('Subject Name: ', subject_name)
    print("="*90)
    band_wise_data_path =  datafiles_path + subject_name + '/rawfiles/'
    mypath = band_wise_data_path + subject_name
    data = pd.read_csv(mypath + '.csv')
    data_col = data.columns
    # Do min max scalling
    scaler = MinMaxScaler()
    scaler.fit(np.array(data))
    data_arr = scaler.transform(np.array(data))
    data = pd.DataFrame(data_arr, columns = data_col)
    for class_label in class_labels:
        print('Class Label: ', class_label)
        link = deap_dataset_path + subject_name + '.dat'
        with open(link, 'rb') as f:
            raw_data = pickle.load(f, encoding = 'latin1')
        labels = raw_data['labels']
        em_labels = emotion_label(labels, class_label) # get the emotion labels
        channel_name = get_fisher_score(subject_name, em_labels) # get the fscore of all channels
        optimal_channel_name = growing_phase(channel_name) # get the optimal channels name
# Out:
# ==========================================================================================
# Subject Name:  s01
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['Fz', 'FC2', 'P8', 'CP6', 'CP5', 'Fp1']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['P7', 'Fp1', 'O1', 'AF3', 'AF4', 'O2', 'FC1', 'P4']
# Class Label:  all
# Accuracy in Growing Phase:  0.525
# No of selected channels in Growing Phase:  14
# Channels selected in Growing Phase:  ['P7', 'Fp2', 'P8', 'T8', 'CP6', 'FC5', 'CP5', 'Fp1', 'F8', 'FC2', 'C4', 'O2', 'CP2', 'Cz']
#
#
# ==========================================================================================
# Subject Name:  s02
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['AF3', 'F4', 'F7', 'O1', 'FC6', 'Fz', 'CP1', 'T7']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.575
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['FC2', 'P7', 'FC6', 'O1', 'O2']
# Class Label:  all
# Accuracy in Growing Phase:  0.5
# No of selected channels in Growing Phase:  19
# Channels selected in Growing Phase:  ['AF3', 'F7', 'Fz', 'CP1', 'CP5', 'P4', 'F8', 'CP2', 'FC2', 'PO4', 'C4', 'Fp1', 'FC5', 'T7', 'CP6', 'O2', 'T8', 'Cz', 'Oz']
#
#
# ==========================================================================================
# Subject Name:  s03
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['O2', 'F3', 'F7', 'FC1', 'T7', 'Fp1', 'AF3', 'F4']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['F3', 'AF4']
# Class Label:  all
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['O2', 'F7']
#
#
# ==========================================================================================
# Subject Name:  s04
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  30
# Channels selected in Growing Phase:  ['O2', 'P8', 'O1', 'CP2', 'Cz', 'P7', 'F8', 'CP1', 'PO4', 'P4', 'Fp2', 'F7', 'CP5', 'CP6', 'F4', 'Oz', 'FC6', 'PO3', 'FC1', 'C3', 'AF4', 'FC5', 'Fz', 'Fp1', 'AF3', 'Pz', 'T8', 'FC2', 'T7', 'F3']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  26
# Channels selected in Growing Phase:  ['P8', 'O1', 'CP2', 'Cz', 'Fp1', 'Fp2', 'F3', 'CP1', 'PO4', 'P4', 'F7', 'F4', 'P7', 'CP5', 'O2', 'C4', 'Oz', 'AF3', 'FC6', 'CP6', 'FC1', 'F8', 'AF4', 'Pz', 'FC2', 'P3']
# Class Label:  all
# Accuracy in Growing Phase:  0.5
# No of selected channels in Growing Phase:  17
# Channels selected in Growing Phase:  ['P8', 'Cz', 'CP2', 'O1', 'O2', 'C4', 'Fp2', 'CP1', 'PO4', 'P4', 'P7', 'Fp1', 'F7', 'F4', 'CP5', 'Oz', 'F8']
#
#
# ==========================================================================================
# Subject Name:  s05
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  19
# Channels selected in Growing Phase:  ['C4', 'Cz', 'T8', 'PO4', 'P4', 'CP5', 'Fz', 'Pz', 'P7', 'FC2', 'FC6', 'Fp1', 'C3', 'Oz', 'F7', 'F3', 'PO3', 'AF3', 'T7']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.425
# No of selected channels in Growing Phase:  15
# Channels selected in Growing Phase:  ['Fz', 'P7', 'T7', 'O2', 'FC6', 'Oz', 'O1', 'PO4', 'Cz', 'P8', 'FC1', 'T8', 'Fp2', 'CP5', 'C3']
# Class Label:  all
# Accuracy in Growing Phase:  0.35
# No of selected channels in Growing Phase:  26
# Channels selected in Growing Phase:  ['Fz', 'PO4', 'P7', 'FC1', 'O2', 'T7', 'Fp1', 'F3', 'F7', 'Oz', 'CP2', 'Fp2', 'P8', 'Cz', 'F8', 'C4', 'CP1', 'FC5', 'P4', 'C3', 'O1', 'Pz', 'AF3', 'CP5', 'P3', 'PO3']
#
#
# ==========================================================================================
# Subject Name:  s06
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['P4', 'FC6', 'CP2', 'Fp1', 'F3']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  10
# Channels selected in Growing Phase:  ['C3', 'AF4', 'P7', 'F4', 'Oz', 'Fp2', 'T8', 'FC6', 'O2', 'C4']
# Class Label:  all
# Accuracy in Growing Phase:  0.475
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['P4', 'CP1', 'C3', 'Pz', 'P3', 'Fp2', 'F3']
#
#
# ==========================================================================================
# Subject Name:  s07
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['PO4', 'Oz', 'F8', 'Fp1', 'F3']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  15
# Channels selected in Growing Phase:  ['FC1', 'F3', 'O1', 'C4', 'C3', 'CP6', 'T7', 'CP2', 'CP5', 'O2', 'P8', 'Fz', 'Cz', 'F8', 'Fp2']
# Class Label:  all
# Accuracy in Growing Phase:  0.45
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['PO4', 'Pz', 'Oz', 'P3']
#
#
# ==========================================================================================
# Subject Name:  s08
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  13
# Channels selected in Growing Phase:  ['Fp1', 'CP6', 'O2', 'Pz', 'C4', 'FC2', 'P3', 'PO3', 'AF4', 'CP5', 'CP1', 'P4', 'Fp2']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.625
# No of selected channels in Growing Phase:  16
# Channels selected in Growing Phase:  ['T8', 'Fp1', 'FC6', 'O1', 'Pz', 'P3', 'FC2', 'Cz', 'CP1', 'Fz', 'PO3', 'CP5', 'CP2', 'AF3', 'AF4', 'FC1']
# Class Label:  all
# Accuracy in Growing Phase:  0.4
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['Fp1', 'CP6']
#
#
# ==========================================================================================
# Subject Name:  s09
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.875
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['T7', 'AF4', 'T8', 'Oz', 'P8']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['AF4', 'T7', 'P8', 'AF3', 'F7']
# Class Label:  all
# Accuracy in Growing Phase:  0.55
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['AF4', 'T7', 'T8', 'Oz', 'P8']
#
#
# ==========================================================================================
# Subject Name:  s10
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  15
# Channels selected in Growing Phase:  ['P3', 'CP6', 'Fz', 'O2', 'FC6', 'T7', 'FC5', 'Oz', 'T8', 'CP5', 'FC1', 'Fp1', 'P7', 'C4', 'PO4']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  18
# Channels selected in Growing Phase:  ['FC1', 'Fp1', 'F3', 'Oz', 'F4', 'F7', 'Cz', 'FC6', 'FC2', 'O1', 'Fp2', 'CP2', 'F8', 'P3', 'Fz', 'P8', 'CP6', 'O2']
# Class Label:  all
# Accuracy in Growing Phase:  0.5
# No of selected channels in Growing Phase:  11
# Channels selected in Growing Phase:  ['FC1', 'T8', 'P3', 'T7', 'Fp1', 'CP5', 'PO4', 'P7', 'F4', 'PO3', 'CP2']
#
#
# ==========================================================================================
# Subject Name:  s11
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.375
# No of selected channels in Growing Phase:  25
# Channels selected in Growing Phase:  ['P4', 'F4', 'P8', 'C3', 'O2', 'O1', 'PO4', 'Cz', 'PO3', 'T8', 'Oz', 'CP6', 'C4', 'F7', 'CP2', 'P3', 'F8', 'Fz', 'P7', 'FC2', 'Pz', 'FC6', 'AF3', 'CP5', 'T7']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  1
# Channels selected in Growing Phase:  ['T7']
# Class Label:  all
# Accuracy in Growing Phase:  0.45
# No of selected channels in Growing Phase:  15
# Channels selected in Growing Phase:  ['F4', 'P8', 'Cz', 'O2', 'F7', 'Oz', 'T8', 'FC2', 'FC6', 'Fz', 'FC5', 'Pz', 'AF3', 'CP1', 'AF4']
#
#
# ==========================================================================================
# Subject Name:  s12
# ==========================================================================================
# Class Label:  valence

# %% [markdown]
# # Taking all the channels

# %%
for subject_name in subject_names[0:32]:
    print('\n')
    print('='*90)
    print('Subject Name: ', subject_name)
    print('='*90)
    band_wise_data_path =  datafiles_path + subject_name + '/rawfiles/'
    mypath = band_wise_data_path + subject_name
    data = pd.read_csv(mypath + '.csv')
    data_col = data.columns
    # Do min max scalling
    scaler = MinMaxScaler()
    scaler.fit(np.array(data))
    data_arr = scaler.transform(np.array(data))
    data = pd.DataFrame(data_arr, columns = data_col)
    for class_label in class_labels:
        print('Class Label: ', class_label)
        link = deap_dataset_path + subject_name + '.dat'
        with open(link, 'rb') as f:
            raw_data = pickle.load(f, encoding = 'latin1')
        labels = raw_data['labels']
        em_labels = emotion_label(labels, class_label) # get the emotion labels
        acc = svmclassifier(eeg_channels, data)
        print('Accuarcy taking all the channels: ', acc)
# Out:
# ==========================================================================================
# Subject Name:  s01
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.375
# Class Label:  arousal
# Accuarcy taking all the channels:  0.6
# Class Label:  all
# Accuarcy taking all the channels:  0.325
#
#
# ==========================================================================================
# Subject Name:  s02
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.6
# Class Label:  arousal
# Accuarcy taking all the channels:  0.25
# Class Label:  all
# Accuarcy taking all the channels:  0.375
#
#
# ==========================================================================================
# Subject Name:  s03
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.75
# Class Label:  arousal
# Accuarcy taking all the channels:  0.675
# Class Label:  all
# Accuarcy taking all the channels:  0.35
#
#
# ==========================================================================================
# Subject Name:  s04
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.65
# Class Label:  arousal
# Accuarcy taking all the channels:  0.65
# Class Label:  all
# Accuarcy taking all the channels:  0.5
#
#
# ==========================================================================================
# Subject Name:  s05
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.725
# Class Label:  arousal
# Accuarcy taking all the channels:  0.375
# Class Label:  all
# Accuarcy taking all the channels:  0.275
#
#
# ==========================================================================================
# Subject Name:  s06
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.75
# Class Label:  arousal
# Accuarcy taking all the channels:  0.55
# Class Label:  all
# Accuarcy taking all the channels:  0.35
#
#
# ==========================================================================================
# Subject Name:  s07
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.675
# Class Label:  arousal
# Accuarcy taking all the channels:  0.6
# Class Label:  all
# Accuarcy taking all the channels:  0.3
#
#
# ==========================================================================================
# Subject Name:  s08
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.575
# Class Label:  arousal
# Accuarcy taking all the channels:  0.55
# Class Label:  all
# Accuarcy taking all the channels:  0.325
#
#
# ==========================================================================================
# Subject Name:  s09
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.7
# Class Label:  arousal
# Accuarcy taking all the channels:  0.575
# Class Label:  all
# Accuarcy taking all the channels:  0.375
#
#
# ==========================================================================================
# Subject Name:  s10
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.625
# Class Label:  arousal
# Accuarcy taking all the channels:  0.7
# Class Label:  all
# Accuarcy taking all the channels:  0.45
#
#
# ==========================================================================================
# Subject Name:  s11
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.35
# Class Label:  arousal
# Accuarcy taking all the channels:  0.7
# Class Label:  all
# Accuarcy taking all the channels:  0.425
#
#
# ==========================================================================================
# Subject Name:  s12
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.6
# Class Label:  arousal
# Accuarcy taking all the channels:  0.775
# Class Label:  all
# Accuarcy taking all the channels:  0.5
#
#
# ==========================================================================================
# Subject Name:  s13
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.775
# Class Label:  arousal
# Accuarcy taking all the channels:  0.75
# Class Label:  all
# Accuarcy taking all the channels:  0.575
#
#
# ==========================================================================================
# Subject Name:  s14
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.65
# Class Label:  arousal
# Accuarcy taking all the channels:  0.65
# Class Label:  all
# Accuarcy taking all the channels:  0.5
#
#
# ==========================================================================================
# Subject Name:  s15
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.675
# Class Label:  arousal
# Accuarcy taking all the channels:  0.55
# Class Label:  all
# Accuarcy taking all the channels:  0.275
#
#
# ==========================================================================================
# Subject Name:  s16
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.6
# Class Label:  arousal
# Accuarcy taking all the channels:  0.65
# Class Label:  all
# Accuarcy taking all the channels:  0.325
#
#
# ==========================================================================================
# Subject Name:  s17
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.425
# Class Label:  arousal
# Accuarcy taking all the channels:  0.775
# Class Label:  all
# Accuarcy taking all the channels:  0.375
#
#
# ==========================================================================================
# Subject Name:  s18
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.775
# Class Label:  arousal
# Accuarcy taking all the channels:  0.675
# Class Label:  all
# Accuarcy taking all the channels:  0.275
#
#
# ==========================================================================================
# Subject Name:  s19
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.7
# Class Label:  arousal
# Accuarcy taking all the channels:  0.625
# Class Label:  all
# Accuarcy taking all the channels:  0.4
#
#
# ==========================================================================================
# Subject Name:  s20
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.65
# Class Label:  arousal
# Accuarcy taking all the channels:  0.75
# Class Label:  all
# Accuarcy taking all the channels:  0.6
#
#
# ==========================================================================================
# Subject Name:  s21
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.25
# Class Label:  arousal
# Accuarcy taking all the channels:  0.775
# Class Label:  all
# Accuarcy taking all the channels:  0.425
#
#
# ==========================================================================================
# Subject Name:  s22
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.65
# Class Label:  arousal
# Accuarcy taking all the channels:  0.575
# Class Label:  all
# Accuarcy taking all the channels:  0.45
#
#
# ==========================================================================================
# Subject Name:  s23
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.625
# Class Label:  arousal
# Accuarcy taking all the channels:  0.7
# Class Label:  all
# Accuarcy taking all the channels:  0.425
#
#
# ==========================================================================================
# Subject Name:  s24
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.575
# Class Label:  arousal
# Accuarcy taking all the channels:  0.825
# Class Label:  all
# Accuarcy taking all the channels:  0.475
#
#
# ==========================================================================================
# Subject Name:  s25
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.55
# Class Label:  arousal
# Accuarcy taking all the channels:  0.575
# Class Label:  all
# Accuarcy taking all the channels:  0.375
#
#
# ==========================================================================================
# Subject Name:  s26
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.5
# Class Label:  arousal
# Accuarcy taking all the channels:  0.65
# Class Label:  all
# Accuarcy taking all the channels:  0.5
#
#
# ==========================================================================================
# Subject Name:  s27
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.75
# Class Label:  arousal
# Accuarcy taking all the channels:  0.625
# Class Label:  all
# Accuarcy taking all the channels:  0.55
#
#
# ==========================================================================================
# Subject Name:  s28
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.675
# Class Label:  arousal
# Accuarcy taking all the channels:  0.55
# Class Label:  all
# Accuarcy taking all the channels:  0.375
#
#
# ==========================================================================================
# Subject Name:  s29
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.55
# Class Label:  arousal
# Accuarcy taking all the channels:  0.7
# Class Label:  all
# Accuarcy taking all the channels:  0.475
#
#
# ==========================================================================================
# Subject Name:  s30
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.625
# Class Label:  arousal
# Accuarcy taking all the channels:  0.575
# Class Label:  all
# Accuarcy taking all the channels:  0.175
#
#
# ==========================================================================================
# Subject Name:  s31
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.525
# Class Label:  arousal
# Accuarcy taking all the channels:  0.675
# Class Label:  all
# Accuarcy taking all the channels:  0.425
#
#
# ==========================================================================================
# Subject Name:  s32
# ==========================================================================================
# Class Label:  valence
# Accuarcy taking all the channels:  0.6
# Class Label:  arousal
# Accuarcy taking all the channels:  0.5
# Class Label:  all
# Accuarcy taking all the channels:  0.375
