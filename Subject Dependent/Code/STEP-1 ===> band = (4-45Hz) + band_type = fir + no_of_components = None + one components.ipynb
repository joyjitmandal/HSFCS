# %%
# Importing python Library
import mne, os, time, pickle, warnings, itertools, copy, sys, shutil
from mne.filter import filter_data as bandpass_filter
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import signal
from sklearn import svm
from scipy.signal import welch, butter, lfilter, sosfilt, sosfreqz, freqz
from scipy.integrate import simps
from scipy.stats import f_oneway
from tqdm import tqdm
from mne.preprocessing import ICA
from sklearn.decomposition import FastICA
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from skfeature.utility.construct_W import construct_W
from scipy.sparse import diags
warnings.filterwarnings('ignore')

# %%
def SignalPreProcess(eeg_rawdata):
    """
    :param eeg_rawdata: numpy array with the shape of (n_channels, n_samples)
    :return: filtered EEG raw data
    """
    assert eeg_rawdata.shape[0] == 32
    eeg_rawdata = np.array(eeg_rawdata)

    ch_names = ["Fp1", "AF3", "F3", "F7", "FC5", "FC1", "C3", "T7", "CP5", "CP1", "P3", "P7", "PO3", "O1", "Oz", 
                "Pz", "Fp2", "AF4", "Fz", "F4", "F8", "FC6", "FC2", "Cz", "C4", "T8", "CP6", "CP2", "P4", "P8",
                "PO4", "O2"]
  
    info = mne.create_info(ch_names = ch_names, ch_types = ['eeg' for _ in range(32)], sfreq = 128, verbose=False)
    raw_data = mne.io.RawArray(eeg_rawdata, info, verbose = False)
    raw_data.load_data(verbose = False).filter(l_freq = 4, h_freq = 48, method = 'iir', verbose = False)
    ica = ICA(n_components = N_C, random_state = 97, verbose = False)
    ica.fit(raw_data)
    eog_indices, eog_scores = ica.find_bads_eog(raw_data, ch_name = 'Fp1', verbose = None)
    #ica.plot_scores(eog_scores)
    a = abs(eog_scores).tolist()
    if(droping_components == 'one'):
        ica.exclude = [a.index(max(a))]
    else: # find two maximum scores
        a_2 = a.copy()
        a.sort(reverse = True)
        exclude_index = []
        for i in range(0, 2):
            for j in range(0, len(a_2)):
                if(a[i]==a_2[j]):
                    exclude_index.append(j)
        ica.exclude = exclude_index
    ica.apply(raw_data, verbose = False)
    # common average reference
    raw_data.set_eeg_reference('average', ch_type = 'eeg')#, projection = True)
    filted_eeg_rawdata = np.array(raw_data.get_data())
    return filted_eeg_rawdata

def signal_pro(input_data):
    for i in range(input_data.shape[0]):
        input_data[i] = SignalPreProcess(input_data[i].copy())
    return input_data

# %%
sf = 128 # sampling frequency 128 Hz

# %%
theta_band_range = (4, 8)   # drownsiness, emotional connection, intuition, creativity
alpha_band_range = (8, 12)  # reflection, relaxation
beta_band_range = (12, 30)  # concentration, problem solving, memory
gamma_band_range = (30, 45) # cognition, perception, learning, multi-tasking

# %%
def get_csv_file(subject, reduced_data, labels):
    eeg_theta, eeg_alpha, eeg_beta, eeg_gamma = [], [], [], []
    channels_theta, channels_alpha, channels_beta, channels_gamma = [], [], [], []
    for video_no in range (len(reduced_data)):
        for channel_no in range (len(reduced_data[0])):
            input_data = reduced_data[video_no, channel_no].copy()
            # Compute the modified periodogram (Welch)
            freqs, psd = welch(input_data, sf)
            # Find closest indices of band in frequency vector
            theta_idx_band = np.logical_and(freqs >= theta_band_range[0], freqs <= theta_band_range[1])
            alpha_idx_band = np.logical_and(freqs >= alpha_band_range[0], freqs <= alpha_band_range[1])
            beta_idx_band = np.logical_and(freqs >= beta_band_range[0], freqs <= beta_band_range[1])
            gamma_idx_band = np.logical_and(freqs >= gamma_band_range[0], freqs <= gamma_band_range[1])

            eeg_theta.append(np.mean(psd[theta_idx_band])) #mean of the frequency bands)
            eeg_alpha.append(np.mean(psd[alpha_idx_band]))
            eeg_beta.append(np.mean(psd[beta_idx_band]))
            eeg_gamma.append(np.mean(psd[gamma_idx_band]))
    eeg_theta = np.reshape(eeg_theta, (40, 32)) # 40 videos and 32 channels theta band power
    eeg_alpha = np.reshape(eeg_alpha, (40, 32))
    eeg_beta = np.reshape(eeg_beta, (40, 32))
    eeg_gamma = np.reshape(eeg_gamma, (40, 32))
    
    for i in range(0, len(eeg_channels)):
        channels_theta.append(eeg_channels[i] + '_theta')
        channels_alpha.append(eeg_channels[i] + '_alpha')
        channels_gamma.append(eeg_channels[i] + '_gamma')
        channels_beta.append(eeg_channels[i] + '_beta')
        
    df_theta = pd.DataFrame(eeg_theta, columns = channels_theta)
    df_alpha = pd.DataFrame(eeg_alpha, columns = channels_alpha)
    df_beta = pd.DataFrame(eeg_beta, columns = channels_beta)
    df_gamma = pd.DataFrame(eeg_gamma, columns = channels_gamma)
    
    # make a directory to save the csv file
    new_path = newpath + subject
    try:
        os.mkdir(new_path)
        os.mkdir(new_path + '/rawfiles')
    except:
        # If directory exists then delete that directory
        shutil.rmtree(new_path)
        # then make the new directory
        os.mkdir(new_path)
        os.mkdir(new_path + '/rawfiles')
    df_theta.to_csv(new_path + '/rawfiles/' + subject + '_theta.csv', index = False, encoding = 'utf-8-sig')
    df_alpha.to_csv(new_path + '/rawfiles/' + subject + '_alpha.csv', index = False, encoding = 'utf-8-sig')
    df_beta.to_csv(new_path + '/rawfiles/' + subject  + '_beta.csv', index = False, encoding = 'utf-8-sig')
    df_gamma.to_csv(new_path + '/rawfiles/' + subject + '_gamma.csv', index = False, encoding = 'utf-8-sig')
    #===========================   ALL Bands   ==================================
    frames = [df_theta, df_alpha, df_beta, df_gamma]
    all_bands = pd.concat(frames, axis = 1) # join these 4 data frame columns wise, row is fixed
    all_bands.to_csv(new_path + '/rawfiles/' + subject + '.csv', index = False, encoding = 'utf-8-sig')
    all_bands_valence, all_bands_arousal, all_bands_all = all_bands.copy(), all_bands.copy(), all_bands.copy()
    all_bands_valence['valence'] = emotion_label(labels, 'valence')
    all_bands_arousal['arousal'] = emotion_label(labels, 'arousal')
    all_bands_all['all'] = emotion_label(labels, 'all')
    all_bands_valence.to_csv(new_path + '/' + subject + '_valence.csv', index = False, encoding = 'utf-8-sig')
    all_bands_arousal.to_csv(new_path + '/' + subject + '_arousal.csv', index = False, encoding = 'utf-8-sig')
    all_bands_all.to_csv(new_path + '/' + subject + '_all.csv', index = False, encoding = 'utf-8-sig')

# %%
def emotion_label(labels, class_label):
    """
    This function gives the valence/arousal and HVHA/HVLA/LAHV/LALV class labels
    """
    em_labels = []
    if(class_label == 'valence'):
        for i in range(0, labels.shape[0]):
            if (labels[i][0]>5): # high valence
                em_labels.append(1)
            else: # low valence
                em_labels.append(0)
        return em_labels
    elif(class_label == 'arousal'):
        for i in range(0, labels.shape[0]):
            if (labels[i][1]>5): # high arousal
                em_labels.append(1)
            else: # low arousal
                em_labels.append(0)
        return em_labels
    elif(class_label == 'all'):
        for i in range(0, labels.shape[0]):
            if (labels[i][0]>5): # high valence
                if(labels[i][1]>5): # high arousal
                    em_labels.append(1) # HVHA
                else:
                    em_labels.append(0) # HVLA
            else: # low valence
                if(labels[i][1]>5): # high arousal
                    em_labels.append(2) # LVHA
                else: # low arousal
                    em_labels.append(3) # LVLA
        return em_labels

# %%
def fisher_score(X, y):
    """
    This function implements the fisher score feature selection, steps are as follows:
    1. Construct the affinity matrix W in fisher score way
    2. For the r-th feature, we define fr = X(:,r), D = diag(W*ones), ones = [1,...,1]', L = D - W
    3. Let fr_hat = fr - (fr'*D*ones)*ones/(ones'*D*ones)
    4. Fisher score for the r-th feature is score = (fr_hat'*D*fr_hat)/(fr_hat'*L*fr_hat)-1
    Input
    -----
    X: {numpy array}, shape (n_samples, n_features)
        input data
    y: {numpy array}, shape (n_samples,)
        input class labels
    Output
    ------
    score: {numpy array}, shape (n_features,)
        fisher score for each feature
    Reference
    ---------
    He, Xiaofei et al. "Laplacian Score for Feature Selection." NIPS 2005.
    Duda, Richard et al. "Pattern classification." John Wiley & Sons, 2012.
    """
    # Construct weight matrix W in a fisherScore way
    kwargs = {"neighbor_mode": "supervised", "fisher_score": True, 'y': y}
    W = construct_W(X, **kwargs)

    # build the diagonal D matrix from affinity matrix W
    D = np.array(W.sum(axis=1))
    L = W
    tmp = np.dot(np.transpose(D), X)
    D = diags(np.transpose(D), [0])
    Xt = np.transpose(X)
    t1 = np.transpose(np.dot(Xt, D.todense()))
    t2 = np.transpose(np.dot(Xt, L.todense()))
    # compute the numerator of Lr
    D_prime = np.sum(np.multiply(t1, X), 0) - np.multiply(tmp, tmp)/D.sum()
    # compute the denominator of Lr
    L_prime = np.sum(np.multiply(t2, X), 0) - np.multiply(tmp, tmp)/D.sum()
    # avoid the denominator of Lr to be 0
    D_prime[D_prime < 1e-12] = 10000
    lap_score = 1 - np.array(np.multiply(L_prime, 1/D_prime))[0, :]

    # compute fisher score from laplacian score, where fisher_score = 1/lap_score - 1
    score = 1.0/lap_score - 1
    return np.transpose(score)

def get_fisher_score(subject_name, em_labels):
    data_theta = pd.read_csv(band_wise_data_path + subject_name + '_theta.csv')
    data_alpha = pd.read_csv(band_wise_data_path + subject_name + '_alpha.csv')
    data_beta = pd.read_csv(band_wise_data_path + subject_name + '_beta.csv')
    data_gamma = pd.read_csv(band_wise_data_path + subject_name + '_gamma.csv')
    
    X_theta, X_alpha = np.array(data_theta), np.array(data_alpha)
    X_beta, X_gamma = np.array(data_beta), np.array(data_gamma)
    y = np.array(em_labels)
    # apply scalling of the given data
    scaler = MinMaxScaler()
    scaler.fit(X_theta)
    X_theta = scaler.transform(X_theta)
    scaler.fit(X_alpha)
    X_alpha = scaler.transform(X_alpha)
    scaler.fit(X_beta)
    X_beta = scaler.transform(X_beta)
    scaler.fit(X_gamma)
    X_gamma = scaler.transform(X_gamma)
    
    fscore_theta, fscore_alpha = fisher_score(X_theta, y), fisher_score(X_alpha, y)
    fscore_beta, fscore_gamma = fisher_score(X_beta, y), fisher_score(X_gamma, y)
    
    # Total Avearge F-Score (Theta, Alpha, Beta, Gamma)
    final_f_score = (fscore_theta + fscore_alpha + fscore_beta + fscore_gamma)/4
    fvalues = pd.Series(final_f_score)
    fvalues.index = eeg_channels
    fvalues.sort_values(ascending = False)
    fvalues.to_csv('fscore_final.csv')
    # for visualization run the below code
    # fvalues.sort_values(ascending = False).plot.bar(figsize=(10,8))
    df = fvalues.sort_values(ascending = False)
    da = pd.DataFrame(df)
    da.to_csv('channel_rank.csv')
    cr = pd.read_csv('channel_rank.csv')
    sort_channel_name = list(cr['Unnamed: 0'])
    os.remove('channel_rank.csv') # delete the csv file
    return sort_channel_name

def emotion_label(labels, class_label):
    em_labels = []
    if(class_label == 'valence'):
        for i in range(0, labels.shape[0]):
            if (labels[i][0]>5): # high valence
                em_labels.append(1)
            else: # low valence
                em_labels.append(0)
        return em_labels
    elif(class_label == 'arousal'):
        for i in range(0, labels.shape[0]):
            if (labels[i][1]>5): # high arousal
                em_labels.append(1)
            else: # low arousal
                em_labels.append(0)
        return em_labels
    elif(class_label == 'all'):
        for i in range(0, labels.shape[0]):
            if (labels[i][0]>5): # high valence
                if(labels[i][1]>5): # high arousal
                    em_labels.append(1) # HVHA
                else:
                    em_labels.append(0) # HVLA
            else: # low valence
                if(labels[i][1]>5): # high arousal
                    em_labels.append(2) # LVHA
                else: # low arousal
                    em_labels.append(3) # LVLA
        return em_labels
    
#Loading the dataset
def svmclassifier(channel_name, data):
    channel_names = []
    for i in range(0, len(channel_name)):
        draft = channel_name[i]
        channel_names.append(draft + "_alpha")
        channel_names.append(draft + "_beta")
        channel_names.append(draft + "_gamma")
        channel_names.append(draft + "_theta")
    x, y = data[channel_names], np.array(em_labels)
    # Implementing cross validation
    k = 40
    kf = KFold(n_splits = k, shuffle = False)
    acc_score = []
    for train_index , test_index in kf.split(x):
        x_train, x_test = x.iloc[train_index,:],x.iloc[test_index,:]
        y_train, y_test = y[train_index] , y[test_index]
        model = svm.SVC(kernel = 'poly')
        model.fit(x_train, y_train)
        pred_values = model.predict(x_test)
        #pred_values = model.predict(x_test)
        acc = accuracy_score(pred_values , y_test)
        acc_score.append(acc)
    avg_acc_score = sum(acc_score)/k
    return avg_acc_score

def growing_phase(channel_name):
    cn = channel_name[0]
    acc = svmclassifier([cn], data.copy())
    cn_list = []
    cn_list.append(cn)
    sort_cn = []
    for i in range(1, len(channel_name)):
        cur_cn = channel_name[i]
        cn_list.append(cur_cn)
        cur_acc = svmclassifier(cn_list, data.copy())
        if(cur_acc<acc):
            cn_list.remove(cur_cn)
        else:
            acc = cur_acc
    print('Accuracy in Growing Phase: ', acc)
    print('No of selected channels in Growing Phase: ', len(cn_list))
    print('Channels selected in Growing Phase: ', cn_list)
    return cn_list

# %%
subject_names = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 
                 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21',
                 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
eeg_channels = np.array(['Fp1', 'AF3', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 
                         'P7', 'PO3', 'O1', 'Oz', 'Pz', 'Fp2', 'AF4', 'Fz', 'F4', 'F8', 'FC6', 
                         'FC2', 'Cz', 'C4', 'T8', 'CP6', 'CP2', 'P4', 'P8', 'PO4', 'O2'])
class_labels = ['valence', 'arousal', 'all']
# deap dataset path # put the path in which deap dataset files are present
deap_dataset_path = '/Users/shyammarjit/Desktop/Brain Computer Interface/Deap Dataset/'
# put the path location of datfiles folder s.t. subject wise folder should contain datafiles
datafiles_path = '/Users/shyammarjit/Desktop/Brain Computer Interface/Hybrid Sequential Forward channel selection (HSFCS)/Subject Dependent/band_45_fir_None_one_new/'
# put the path in which you want to save the csv file
save_csv_path = '/Users/shyammarjit/Desktop/Brain Computer Interface/Hybrid Sequential Forward channel selection (HSFCS)/Subject Dependent'

# %%
# fir filter
N_C = None
droping_components = 'one'

for subject in subject_names[0:32]:
    newpath = save_csv_path + '/band_45_fir_None_one_new/'
    try:
        # If the directory already exists then don't make any new dirctory
        os.mkdir(newpath)
    except:
        pass
    # load the dataset
    with open(deap_dataset_path + subject + '.dat', 'rb') as f:
        raw_data = pickle.load(f, encoding = 'latin1')
    # raw_data has two key 'data' and 'labels'
    data = raw_data['data']
    labels = raw_data['labels']
    # we are excluding 3s pre base line i.e. first 3*128 = 384 data points from time series data
    reduced_eeg_data  = data[0:40, 0:32, 384:8064]
    reduced_data = signal_pro(reduced_eeg_data.copy())
    get_csv_file(subject, reduced_data, labels)
    print('Done: ', subject)
    
    
    #break

    subject_name = subject
    print("\n")
    print("="*90)
    print('Subject Name: ', subject_name)
    print("="*90)
    band_wise_data_path =  datafiles_path + subject_name + '/rawfiles/'
    mypath = band_wise_data_path + subject_name
    data = pd.read_csv(mypath + '.csv')
    data_col = data.columns
    # Do min max scalling
    scaler = MinMaxScaler()
    scaler.fit(np.array(data))
    data_arr = scaler.transform(np.array(data))
    data = pd.DataFrame(data_arr, columns = data_col)
    for class_label in class_labels:
        print('Class Label: ', class_label)
        link = deap_dataset_path + subject_name + '.dat'
        with open(link, 'rb') as f:
            raw_data = pickle.load(f, encoding = 'latin1')
        labels = raw_data['labels']
        em_labels = emotion_label(labels, class_label) # get the emotion labels
        channel_name = get_fisher_score(subject_name, em_labels) # get the fscore of all channels
        optimal_channel_name = growing_phase(channel_name) # get the optimal channels name
# Out:
# Done:  s01
#
#
# ==========================================================================================
# Subject Name:  s01
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['O1', 'PO3', 'P7', 'Oz', 'CP2', 'CP1', 'AF4', 'AF3']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['P7', 'T7']
# Class Label:  all
# Accuracy in Growing Phase:  0.55
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['P7', 'PO3', 'AF4']
# Done:  s02
#
#
# ==========================================================================================
# Subject Name:  s02
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['Fp2', 'FC1', 'Oz', 'CP6', 'Cz', 'T8', 'P8', 'CP2']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['P7', 'F3', 'Fp2', 'T8', 'FC1', 'O2', 'Cz', 'CP6']
# Class Label:  all
# Accuracy in Growing Phase:  0.575
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['Fp2', 'F4', 'F3', 'Fz', 'Oz', 'F7', 'P3', 'O2']
# Done:  s03
#
#
# ==========================================================================================
# Subject Name:  s03
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.85
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['O2', 'F7', 'Fp1', 'P4', 'CP1', 'FC5', 'CP6', 'T8']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['AF4', 'CP1', 'FC2']
# Class Label:  all
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['O2', 'CP2']
# Done:  s04
#
#
# ==========================================================================================
# Subject Name:  s04
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  9
# Channels selected in Growing Phase:  ['O2', 'P3', 'P8', 'T7', 'O1', 'FC6', 'Fz', 'Fp1', 'Pz']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['FC2', 'T8', 'Fz', 'CP6', 'FC5', 'Pz', 'P3']
# Class Label:  all
# Accuracy in Growing Phase:  0.475
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['FC2', 'T8', 'F3', 'Pz', 'Fz', 'PO3']
# Done:  s05
#
#
# ==========================================================================================
# Subject Name:  s05
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['C4', 'Cz', 'Fp1', 'AF4', 'F7', 'T7']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['PO3', 'P3', 'CP5', 'Pz', 'O1', 'T8', 'P8', 'FC6']
# Class Label:  all
# Accuracy in Growing Phase:  0.25
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['F3', 'C4', 'Cz', 'P7', 'CP2', 'CP5', 'CP1', 'P4']
# Done:  s06
#
#
# ==========================================================================================
# Subject Name:  s06
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  13
# Channels selected in Growing Phase:  ['C3', 'Fp2', 'FC5', 'FC2', 'P8', 'P4', 'CP2', 'PO4', 'O1', 'Pz', 'PO3', 'FC1', 'Cz']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  1
# Channels selected in Growing Phase:  ['AF3']
# Class Label:  all
# Accuracy in Growing Phase:  0.45
# No of selected channels in Growing Phase:  18
# Channels selected in Growing Phase:  ['C3', 'FC5', 'FC2', 'Fp1', 'Fp2', 'PO3', 'O1', 'CP6', 'P3', 'CP2', 'O2', 'CP5', 'CP1', 'Pz', 'PO4', 'F8', 'P7', 'T7']
# Done:  s07
#
#
# ==========================================================================================
# Subject Name:  s07
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  12
# Channels selected in Growing Phase:  ['Fp2', 'Cz', 'FC5', 'FC6', 'PO4', 'F4', 'F8', 'F7', 'P4', 'P7', 'C3', 'O1']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['FC1', 'O1', 'F4', 'F3', 'C3', 'F7']
# Class Label:  all
# Accuracy in Growing Phase:  0.475
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['Fp2', 'P3', 'FC5', 'FC6', 'F4', 'C4', 'T7']
# Done:  s08
#
#
# ==========================================================================================
# Subject Name:  s08
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['Fp1', 'T8', 'CP5', 'FC6']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['P3', 'Fz', 'PO3']
# Class Label:  all
# Accuracy in Growing Phase:  0.45
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['Fp1', 'AF3', 'P3', 'Fz', 'F7']
# Done:  s09
#
#
# ==========================================================================================
# Subject Name:  s09
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.85
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['T7', 'P8', 'Oz', 'FC1', 'PO4', 'F7', 'PO3']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['AF4', 'Fz', 'Fp1', 'T7', 'AF3', 'PO3', 'Cz']
# Class Label:  all
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  9
# Channels selected in Growing Phase:  ['T7', 'T8', 'AF4', 'P8', 'Oz', 'FC6', 'FC1', 'CP6', 'P4']
# Done:  s10
#
#
# ==========================================================================================
# Subject Name:  s10
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['P3', 'FC6', 'F4', 'Cz', 'CP2']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.575
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['FC6', 'FC5']
# Class Label:  all
# Accuracy in Growing Phase:  0.45
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['P3', 'FC6', 'F8']
# Done:  s11
#
#
# ==========================================================================================
# Subject Name:  s11
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.475
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['Fp1', 'T7']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  9
# Channels selected in Growing Phase:  ['T7', 'CP1', 'F7', 'P3', 'CP2', 'F8', 'F3', 'FC1', 'FC5']
# Class Label:  all
# Accuracy in Growing Phase:  0.35
# No of selected channels in Growing Phase:  22
# Channels selected in Growing Phase:  ['F4', 'Fz', 'C3', 'Cz', 'Oz', 'P8', 'CP6', 'C4', 'O1', 'PO4', 'PO3', 'O2', 'CP1', 'F7', 'CP2', 'T8', 'FC1', 'FC5', 'P4', 'F3', 'AF4', 'T7']
# Done:  s12
#
#
# ==========================================================================================
# Subject Name:  s12
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['CP1', 'CP2', 'P7', 'P4', 'Pz', 'T8']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.875
# No of selected channels in Growing Phase:  13
# Channels selected in Growing Phase:  ['AF4', 'FC6', 'Cz', 'T8', 'Oz', 'CP6', 'PO4', 'CP1', 'CP2', 'AF3', 'FC1', 'C4', 'PO3']
# Class Label:  all
# Accuracy in Growing Phase:  0.625
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['PO4', 'FC2', 'CP5', 'F4', 'PO3', 'T8']
# Done:  s13
#
#
# ==========================================================================================
# Subject Name:  s13
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  12
# Channels selected in Growing Phase:  ['FC2', 'P7', 'Fz', 'O2', 'P4', 'Cz', 'P8', 'FC1', 'Oz', 'AF3', 'Pz', 'F7']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.85
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['T8', 'P3', 'CP1', 'CP2']
# Class Label:  all
# Accuracy in Growing Phase:  0.575
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['Fz', 'Oz', 'P7', 'P8', 'Fp1']
# Done:  s14
#
#
# ==========================================================================================
# Subject Name:  s14
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  16
# Channels selected in Growing Phase:  ['F7', 'T7', 'T8', 'CP6', 'P8', 'FC2', 'F3', 'AF3', 'CP1', 'Fz', 'P4', 'Pz', 'C3', 'PO4', 'C4', 'PO3']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  11
# Channels selected in Growing Phase:  ['AF3', 'Oz', 'PO3', 'C4', 'AF4', 'Fp2', 'PO4', 'CP1', 'F4', 'F3', 'C3']
# Class Label:  all
# Accuracy in Growing Phase:  0.5
# No of selected channels in Growing Phase:  10
# Channels selected in Growing Phase:  ['F7', 'T7', 'CP6', 'P7', 'P8', 'CP2', 'O2', 'Fz', 'C3', 'P4']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-f2a9e09f903f> in <module>
#      17     # we are excluding 3s pre base line i.e. first 3*128 = 384 data points from time series data
#      18     reduced_eeg_data  = data[0:40, 0:32, 384:8064]
# ---> 19     reduced_data = signal_pro(reduced_eeg_data.copy())
#      20     get_csv_file(subject, reduced_data, labels)
#      21     print('Done: ', subject)
#
# <ipython-input-4-f540d336ef50> in signal_pro(input_data)
#      38 def signal_pro(input_data):
#      39     for i in range(input_data.shape[0]):
# ---> 40         input_data[i] = SignalPreProcess(input_data[i].copy())
#      41     return input_data
#
# <ipython-input-4-f540d336ef50> in SignalPreProcess(eeg_rawdata)
#      15     raw_data.load_data(verbose = False).filter(l_freq = 4, h_freq = 45, method = 'fir', verbose = False)
#      16     ica = ICA(n_components = N_C, random_state = 97, verbose = False)
# ---> 17     ica.fit(raw_data)
#      18     eog_indices, eog_scores = ica.find_bads_eog(raw_data, ch_name = 'Fp1', verbose = None)
#      19     #ica.plot_scores(eog_scores)
#
# <decorator-gen-420> in fit(self, inst, picks, start, stop, decim, reject, flat, tstep, reject_by_annotation, verbose)
#
# /Applications/anaconda3/lib/python3.8/site-packages/mne/preprocessing/ica.py in fit(self, inst, picks, start, stop, decim, reject, flat, tstep, reject_by_annotation, verbose)
#     568
#     569         if isinstance(inst, BaseRaw):
# --> 570             self._fit_raw(inst, picks, start, stop, decim, reject, flat,
#     571                           tstep, reject_by_annotation, verbose)
#     572         else:
#
# /Applications/anaconda3/lib/python3.8/site-packages/mne/preprocessing/ica.py in _fit_raw(self, raw, picks, start, stop, decim, reject, flat, tstep, reject_by_annotation, verbose)
#     612
#     613         self.n_samples_ = data.shape[1]
# --> 614         self._fit(data, 'raw')
#     615
#     616         return self
#
# /Applications/anaconda3/lib/python3.8/site-packages/mne/preprocessing/ica.py in _fit(self, data, fit_type)
#     765             ica = FastICA(
#     766                 whiten=False, random_state=random_state, **self.fit_params)
# --> 767             ica.fit(data[:, sel])
#     768             self.unmixing_matrix_ = ica.components_
#     769             self.n_iter_ = ica.n_iter_
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py in fit(self, X, y)
#     572         self
#     573         """
# --> 574         self._fit(X, compute_sources=False)
#     575         return self
#     576
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py in _fit(self, X, compute_sources)
#     510
#     511         if self.algorithm == 'parallel':
# --> 512             W, n_iter = _ica_par(X1, **kwargs)
#     513         elif self.algorithm == 'deflation':
#     514             W, n_iter = _ica_def(X1, **kwargs)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py in _ica_par(***failed resolving arguments***)
#     106     p_ = float(X.shape[1])
#     107     for ii in range(max_iter):
# --> 108         gwtx, g_wtx = g(np.dot(W, X), fun_args)
#     109         W1 = _sym_decorrelation(np.dot(gwtx, X.T) / p_
#     110                                 - g_wtx[:, np.newaxis] * W)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py in _logcosh(x, fun_args)
#     129
#     130     x *= alpha
# --> 131     gx = np.tanh(x, x)  # apply the tanh inplace
#     132     g_x = np.empty(x.shape[0])
#     133     # XXX compute in chunks to avoid extra allocation
#
# KeyboardInterrupt:

# %%
# iir 
N_C = None
droping_components = 'one'

for subject in subject_names[0:32]:
    newpath = save_csv_path + '/band_45_fir_None_one_new/'
    try:
        # If the directory already exists then don't make any new dirctory
        os.mkdir(newpath)
    except:
        pass
    # load the dataset
    with open(deap_dataset_path + subject + '.dat', 'rb') as f:
        raw_data = pickle.load(f, encoding = 'latin1')
    # raw_data has two key 'data' and 'labels'
    data = raw_data['data']
    labels = raw_data['labels']
    # we are excluding 3s pre base line i.e. first 3*128 = 384 data points from time series data
    reduced_eeg_data  = data[0:40, 0:32, 384:8064]
    reduced_data = signal_pro(reduced_eeg_data.copy())
    get_csv_file(subject, reduced_data, labels)
    print('Done: ', subject)
    
    
    #break

    subject_name = subject
    print("\n")
    print("="*90)
    print('Subject Name: ', subject_name)
    print("="*90)
    band_wise_data_path =  datafiles_path + subject_name + '/rawfiles/'
    mypath = band_wise_data_path + subject_name
    data = pd.read_csv(mypath + '.csv')
    data_col = data.columns
    # Do min max scalling
    scaler = MinMaxScaler()
    scaler.fit(np.array(data))
    data_arr = scaler.transform(np.array(data))
    data = pd.DataFrame(data_arr, columns = data_col)
    for class_label in class_labels:
        print('Class Label: ', class_label)
        link = deap_dataset_path + subject_name + '.dat'
        with open(link, 'rb') as f:
            raw_data = pickle.load(f, encoding = 'latin1')
        labels = raw_data['labels']
        em_labels = emotion_label(labels, class_label) # get the emotion labels
        channel_name = get_fisher_score(subject_name, em_labels) # get the fscore of all channels
        optimal_channel_name = growing_phase(channel_name) # get the optimal channels name
# Out:
# Done:  s01
#
#
# ==========================================================================================
# Subject Name:  s01
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.625
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['Fz', 'FC2']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  9
# Channels selected in Growing Phase:  ['PO3', 'O1', 'AF4', 'Fz', 'F8', 'F7', 'T7', 'P4', 'O2']
# Class Label:  all
# Accuracy in Growing Phase:  0.525
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['P3', 'PO3', 'P7', 'CP5', 'AF4', 'Fp1']
# Done:  s02
#
#
# ==========================================================================================
# Subject Name:  s02
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  9
# Channels selected in Growing Phase:  ['Fp2', 'FC1', 'Cz', 'Oz', 'T8', 'P8', 'AF4', 'F8', 'FC6']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['P7', 'C3', 'FC6']
# Class Label:  all
# Accuracy in Growing Phase:  0.525
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['Fp2', 'F7', 'T7']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-15ae3a84af15> in <module>
#      18     # we are excluding 3s pre base line i.e. first 3*128 = 384 data points from time series data
#      19     reduced_eeg_data  = data[0:40, 0:32, 384:8064]
# ---> 20     reduced_data = signal_pro(reduced_eeg_data.copy())
#      21     get_csv_file(subject, reduced_data, labels)
#      22     print('Done: ', subject)
#
# <ipython-input-13-1e9a7fd02d44> in signal_pro(input_data)
#      38 def signal_pro(input_data):
#      39     for i in range(input_data.shape[0]):
# ---> 40         input_data[i] = SignalPreProcess(input_data[i].copy())
#      41     return input_data
#
# <ipython-input-13-1e9a7fd02d44> in SignalPreProcess(eeg_rawdata)
#      15     raw_data.load_data(verbose = False).filter(l_freq = 4, h_freq = 45, method = 'iir', verbose = False)
#      16     ica = ICA(n_components = N_C, random_state = 97, verbose = False)
# ---> 17     ica.fit(raw_data)
#      18     eog_indices, eog_scores = ica.find_bads_eog(raw_data, ch_name = 'Fp1', verbose = None)
#      19     #ica.plot_scores(eog_scores)
#
# <decorator-gen-420> in fit(self, inst, picks, start, stop, decim, reject, flat, tstep, reject_by_annotation, verbose)
#
# /Applications/anaconda3/lib/python3.8/site-packages/mne/preprocessing/ica.py in fit(self, inst, picks, start, stop, decim, reject, flat, tstep, reject_by_annotation, verbose)
#     568
#     569         if isinstance(inst, BaseRaw):
# --> 570             self._fit_raw(inst, picks, start, stop, decim, reject, flat,
#     571                           tstep, reject_by_annotation, verbose)
#     572         else:
#
# /Applications/anaconda3/lib/python3.8/site-packages/mne/preprocessing/ica.py in _fit_raw(self, raw, picks, start, stop, decim, reject, flat, tstep, reject_by_annotation, verbose)
#     612
#     613         self.n_samples_ = data.shape[1]
# --> 614         self._fit(data, 'raw')
#     615
#     616         return self
#
# /Applications/anaconda3/lib/python3.8/site-packages/mne/preprocessing/ica.py in _fit(self, data, fit_type)
#     765             ica = FastICA(
#     766                 whiten=False, random_state=random_state, **self.fit_params)
# --> 767             ica.fit(data[:, sel])
#     768             self.unmixing_matrix_ = ica.components_
#     769             self.n_iter_ = ica.n_iter_
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py in fit(self, X, y)
#     572         self
#     573         """
# --> 574         self._fit(X, compute_sources=False)
#     575         return self
#     576
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py in _fit(self, X, compute_sources)
#     510
#     511         if self.algorithm == 'parallel':
# --> 512             W, n_iter = _ica_par(X1, **kwargs)
#     513         elif self.algorithm == 'deflation':
#     514             W, n_iter = _ica_def(X1, **kwargs)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py in _ica_par(***failed resolving arguments***)
#     106     p_ = float(X.shape[1])
#     107     for ii in range(max_iter):
# --> 108         gwtx, g_wtx = g(np.dot(W, X), fun_args)
#     109         W1 = _sym_decorrelation(np.dot(gwtx, X.T) / p_
#     110                                 - g_wtx[:, np.newaxis] * W)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py in _logcosh(x, fun_args)
#     129
#     130     x *= alpha
# --> 131     gx = np.tanh(x, x)  # apply the tanh inplace
#     132     g_x = np.empty(x.shape[0])
#     133     # XXX compute in chunks to avoid extra allocation
#
# KeyboardInterrupt:

# %%
# 48 iir
# fir filter
N_C = None
droping_components = 'one'

for subject in subject_names[0:32]:
    newpath = save_csv_path + '/band_45_fir_None_one_new/'
    try:
        # If the directory already exists then don't make any new dirctory
        os.mkdir(newpath)
    except:
        pass
    # load the dataset
    with open(deap_dataset_path + subject + '.dat', 'rb') as f:
        raw_data = pickle.load(f, encoding = 'latin1')
    # raw_data has two key 'data' and 'labels'
    data = raw_data['data']
    labels = raw_data['labels']
    # we are excluding 3s pre base line i.e. first 3*128 = 384 data points from time series data
    reduced_eeg_data  = data[0:40, 0:32, 384:8064]
    reduced_data = signal_pro(reduced_eeg_data.copy())
    get_csv_file(subject, reduced_data, labels)
    print('Done: ', subject)
    
    
    #break

    subject_name = subject
    print("\n")
    print("="*90)
    print('Subject Name: ', subject_name)
    print("="*90)
    band_wise_data_path =  datafiles_path + subject_name + '/rawfiles/'
    mypath = band_wise_data_path + subject_name
    data = pd.read_csv(mypath + '.csv')
    data_col = data.columns
    # Do min max scalling
    scaler = MinMaxScaler()
    scaler.fit(np.array(data))
    data_arr = scaler.transform(np.array(data))
    data = pd.DataFrame(data_arr, columns = data_col)
    for class_label in class_labels:
        print('Class Label: ', class_label)
        link = deap_dataset_path + subject_name + '.dat'
        with open(link, 'rb') as f:
            raw_data = pickle.load(f, encoding = 'latin1')
        labels = raw_data['labels']
        em_labels = emotion_label(labels, class_label) # get the emotion labels
        channel_name = get_fisher_score(subject_name, em_labels) # get the fscore of all channels
        optimal_channel_name = growing_phase(channel_name) # get the optimal channels name
# Out:
# Done:  s01
#
#
# ==========================================================================================
# Subject Name:  s01
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['Fz', 'F4', 'PO3', 'Fp1']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.875
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['P7', 'CP1', 'Oz']
# Class Label:  all
# Accuracy in Growing Phase:  0.5
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['P7', 'P8', 'FC1']
# Done:  s02
#
#
# ==========================================================================================
# Subject Name:  s02
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  16
# Channels selected in Growing Phase:  ['Fp2', 'FC1', 'Cz', 'CP2', 'Fp1', 'P4', 'C4', 'F3', 'O2', 'P3', 'F7', 'FC5', 'O1', 'AF4', 'T7', 'F8']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['F3', 'FC2', 'P7', 'F8', 'Fp1', 'T8', 'CP5', 'P3']
# Class Label:  all
# Accuracy in Growing Phase:  0.525
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['Fp2', 'O1', 'Cz', 'Fp1', 'Fz', 'P3']
# Done:  s03
#
#
# ==========================================================================================
# Subject Name:  s03
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['O2', 'AF4']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  1
# Channels selected in Growing Phase:  ['AF4']
# Class Label:  all
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  1
# Channels selected in Growing Phase:  ['O2']
# Done:  s04
#
#
# ==========================================================================================
# Subject Name:  s04
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['P3', 'C4', 'F8', 'T7', 'C3', 'FC5', 'O1', 'Cz']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['FC2', 'T8', 'CP6', 'Fz', 'FC5', 'Pz']
# Class Label:  all
# Accuracy in Growing Phase:  0.475
# No of selected channels in Growing Phase:  23
# Channels selected in Growing Phase:  ['FC2', 'F3', 'T8', 'Pz', 'Fz', 'PO3', 'FC5', 'CP2', 'Fp1', 'FC6', 'O1', 'P4', 'CP1', 'Oz', 'Fp2', 'AF3', 'F8', 'F7', 'F4', 'T7', 'PO4', 'CP5', 'Cz']
# Done:  s05
#
#
# ==========================================================================================
# Subject Name:  s05
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['C4', 'Cz']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['PO3', 'T8', 'O1', 'T7', 'Oz']
# Class Label:  all
# Accuracy in Growing Phase:  0.225
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['F3', 'Cz', 'FC2', 'Oz']
# Done:  s06
#
#
# ==========================================================================================
# Subject Name:  s06
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  11
# Channels selected in Growing Phase:  ['C3', 'FC5', 'CP6', 'Fz', 'Fp2', 'FC2', 'FC6', 'Fp1', 'C4', 'CP1', 'CP2']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.575
# No of selected channels in Growing Phase:  11
# Channels selected in Growing Phase:  ['T8', 'AF3', 'FC1', 'F4', 'Oz', 'F3', 'FC6', 'Cz', 'F7', 'FC5', 'CP6']
# Class Label:  all
# Accuracy in Growing Phase:  0.5
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['FC1', 'Oz', 'AF3', 'PO3', 'Cz', 'Fp1', 'Fz', 'AF4']
# Done:  s07
#
#
# ==========================================================================================
# Subject Name:  s07
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['PO4', 'Oz', 'Cz', 'T7', 'O2', 'P4']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['FC1', 'AF4', 'PO3', 'Fp1']
# Class Label:  all
# Accuracy in Growing Phase:  0.45
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['F3', 'P3', 'F4', 'FC6', 'FC5', 'PO3', 'AF4', 'P7']
# Done:  s08
#
#
# ==========================================================================================
# Subject Name:  s08
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['Fp1', 'AF3']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['Fz', 'P3', 'PO3', 'FC2']
# Class Label:  all
# Accuracy in Growing Phase:  0.425
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['Fp1', 'Fz', 'FC6']
# Done:  s09
#
#
# ==========================================================================================
# Subject Name:  s09
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.875
# No of selected channels in Growing Phase:  19
# Channels selected in Growing Phase:  ['T8', 'T7', 'AF4', 'P8', 'Oz', 'FC1', 'CP6', 'P7', 'Pz', 'P3', 'FC2', 'P4', 'Fp1', 'F3', 'PO4', 'F4', 'AF3', 'CP2', 'O2']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['AF4', 'Fp1', 'Fz', 'T7', 'AF3', 'PO3']
# Class Label:  all
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['T7', 'T8', 'FC1', 'Cz', 'P7', 'Pz', 'PO4', 'F4']
# Done:  s10
#
#
# ==========================================================================================
# Subject Name:  s10
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['P3', 'FC6', 'CP2', 'F8', 'T7', 'F3', 'PO4']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.575
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['FC6', 'P4']
# Class Label:  all
# Accuracy in Growing Phase:  0.45
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['P3', 'FC6', 'F8']
# Done:  s11
#
#
# ==========================================================================================
# Subject Name:  s11
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.625
# No of selected channels in Growing Phase:  13
# Channels selected in Growing Phase:  ['Fp1', 'Fp2', 'AF3', 'CP5', 'P7', 'C3', 'PO4', 'F4', 'Cz', 'P8', 'FC5', 'T8', 'CP1']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.625
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['T7', 'CP1', 'F7', 'F3', 'FC1', 'FC5', 'AF3', 'Fp2']
# Class Label:  all
# Accuracy in Growing Phase:  0.375
# No of selected channels in Growing Phase:  30
# Channels selected in Growing Phase:  ['F4', 'Fz', 'C3', 'Cz', 'Oz', 'P8', 'CP6', 'C4', 'CP1', 'O1', 'PO4', 'Pz', 'PO3', 'O2', 'F7', 'FC5', 'FC1', 'CP2', 'T8', 'P3', 'P4', 'F8', 'P7', 'F3', 'FC2', 'FC6', 'Fp2', 'AF4', 'Fp1', 'T7']
# Done:  s12
#
#
# ==========================================================================================
# Subject Name:  s12
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  9
# Channels selected in Growing Phase:  ['CP1', 'C3', 'CP2', 'P7', 'F3', 'F4', 'Pz', 'Fz', 'F7']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.85
# No of selected channels in Growing Phase:  12
# Channels selected in Growing Phase:  ['AF4', 'FC6', 'Fp2', 'Cz', 'PO4', 'F3', 'O1', 'AF3', 'FC1', 'C4', 'PO3', 'O2']
# Class Label:  all
# Accuracy in Growing Phase:  0.625
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['CP1', 'FC2', 'CP5', 'Oz']
# Done:  s13
#
#
# ==========================================================================================
# Subject Name:  s13
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  11
# Channels selected in Growing Phase:  ['P7', 'P4', 'AF3', 'Cz', 'Oz', 'FC2', 'Pz', 'F7', 'P8', 'F3', 'F4']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.85
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['PO3', 'P3', 'T8', 'O1', 'FC1', 'Cz']
# Class Label:  all
# Accuracy in Growing Phase:  0.55
# No of selected channels in Growing Phase:  22
# Channels selected in Growing Phase:  ['O2', 'P7', 'Cz', 'FC2', 'P4', 'Fp2', 'AF3', 'Oz', 'Pz', 'F7', 'P8', 'F4', 'C4', 'O1', 'F3', 'AF4', 'CP2', 'T7', 'F8', 'T8', 'FC6', 'PO4']
# Done:  s14
#
#
# ==========================================================================================
# Subject Name:  s14
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  13
# Channels selected in Growing Phase:  ['F7', 'T8', 'F3', 'P8', 'CP6', 'C3', 'Fp2', 'AF3', 'AF4', 'FC5', 'C4', 'Pz', 'P3']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  12
# Channels selected in Growing Phase:  ['AF3', 'P3', 'FC2', 'Fp1', 'C4', 'AF4', 'Fp2', 'PO4', 'O1', 'P4', 'T7', 'Fz']
# Class Label:  all
# Accuracy in Growing Phase:  0.5
# No of selected channels in Growing Phase:  19
# Channels selected in Growing Phase:  ['F7', 'T8', 'T7', 'O2', 'P7', 'Cz', 'CP2', 'P8', 'F3', 'CP1', 'P4', 'CP6', 'FC6', 'C3', 'PO4', 'FC5', 'F4', 'C4', 'PO3']
# Done:  s15
#
#
# ==========================================================================================
# Subject Name:  s15
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  14
# Channels selected in Growing Phase:  ['FC6', 'Pz', 'C3', 'P4', 'O1', 'T8', 'O2', 'F8', 'CP6', 'C4', 'F4', 'Fp2', 'P3', 'P7']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  16
# Channels selected in Growing Phase:  ['FC1', 'P3', 'FC2', 'AF4', 'Fz', 'Fp2', 'Fp1', 'F4', 'CP2', 'CP6', 'F8', 'PO3', 'O1', 'C3', 'C4', 'Pz']
# Class Label:  all
# Accuracy in Growing Phase:  0.525
# No of selected channels in Growing Phase:  13
# Channels selected in Growing Phase:  ['FC6', 'C3', 'PO3', 'CP2', 'F8', 'F4', 'FC2', 'FC1', 'P3', 'Fz', 'AF4', 'C4', 'Fp1']
# Done:  s16
#
#
# ==========================================================================================
# Subject Name:  s16
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  19
# Channels selected in Growing Phase:  ['F3', 'T7', 'O1', 'P3', 'FC5', 'P4', 'P8', 'CP2', 'FC2', 'C4', 'Cz', 'Fp2', 'CP6', 'Fz', 'C3', 'O2', 'FC1', 'P7', 'AF4']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['O2', 'FC1', 'FC6', 'T7', 'Fp1', 'P4', 'C4']
# Class Label:  all
# Accuracy in Growing Phase:  0.475
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['O2', 'FC6', 'T7', 'Pz', 'CP5']
# Done:  s17
#
#
# ==========================================================================================
# Subject Name:  s17
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['CP2', 'FC6', 'O2', 'Fp1']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  9
# Channels selected in Growing Phase:  ['P4', 'Fz', 'FC1', 'F7', 'P8', 'CP6', 'CP2', 'O1', 'Pz']
# Class Label:  all
# Accuracy in Growing Phase:  0.45
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['CP1', 'P4', 'FC5', 'P8']
# Done:  s18
#
#
# ==========================================================================================
# Subject Name:  s18
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.875
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['Oz', 'AF4', 'CP1', 'PO3', 'P4', 'F7']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['O1', 'FC5', 'PO3', 'PO4', 'P3', 'FC6', 'P8', 'F8']
# Class Label:  all
# Accuracy in Growing Phase:  0.525
# No of selected channels in Growing Phase:  9
# Channels selected in Growing Phase:  ['Oz', 'Pz', 'FC1', 'AF4', 'C3', 'P7', 'PO4', 'T7', 'F3']
# Done:  s19
#
#
# ==========================================================================================
# Subject Name:  s19
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.825
# No of selected channels in Growing Phase:  14
# Channels selected in Growing Phase:  ['F7', 'F3', 'CP6', 'C3', 'FC1', 'Pz', 'FC6', 'PO4', 'T8', 'P8', 'FC2', 'CP2', 'F8', 'CP5']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['CP5', 'F4', 'F8', 'P8', 'O2']
# Class Label:  all
# Accuracy in Growing Phase:  0.475
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['O1', 'F7', 'Pz', 'AF4', 'P3', 'FC5', 'Fp2', 'F4']
# Done:  s20
#
#
# ==========================================================================================
# Subject Name:  s20
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['FC1', 'C3', 'CP6', 'P3', 'Fp1', 'F7']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.825
# No of selected channels in Growing Phase:  26
# Channels selected in Growing Phase:  ['F4', 'F8', 'CP5', 'FC6', 'P7', 'AF3', 'FC5', 'Fp1', 'F7', 'Fz', 'PO3', 'Oz', 'AF4', 'CP6', 'Fp2', 'O1', 'FC2', 'T8', 'CP1', 'P4', 'C4', 'Cz', 'CP2', 'C3', 'T7', 'PO4']
# Class Label:  all
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['P7', 'C3', 'FC1', 'Fp1', 'T7', 'FC5', 'F7', 'F8']
# Done:  s21
#
#
# ==========================================================================================
# Subject Name:  s21
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.525
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['Fp1', 'AF3', 'CP2', 'P8', 'FC2', 'Cz', 'C4']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['F8', 'Oz', 'P3']
# Class Label:  all
# Accuracy in Growing Phase:  0.45
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['P7', 'P4', 'O2', 'Pz']
# Done:  s22
#
#
# ==========================================================================================
# Subject Name:  s22
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['O2', 'C4', 'F3', 'P4', 'Fz', 'AF4']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['Oz', 'FC2', 'FC5', 'CP2', 'CP6', 'P7', 'F7']
# Class Label:  all
# Accuracy in Growing Phase:  0.5
# No of selected channels in Growing Phase:  17
# Channels selected in Growing Phase:  ['FC5', 'C4', 'Fz', 'O2', 'P4', 'AF3', 'FC1', 'CP5', 'FC2', 'Oz', 'AF4', 'C3', 'Fp1', 'F4', 'CP2', 'O1', 'F7']
# Done:  s23
#
#
# ==========================================================================================
# Subject Name:  s23
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['PO4', 'Oz', 'Fz', 'CP2', 'PO3', 'FC1']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  10
# Channels selected in Growing Phase:  ['T7', 'O1', 'O2', 'Fz', 'FC6', 'FC1', 'AF3', 'FC5', 'PO4', 'F7']
# Class Label:  all
# Accuracy in Growing Phase:  0.55
# No of selected channels in Growing Phase:  10
# Channels selected in Growing Phase:  ['T7', 'CP5', 'C3', 'O1', 'CP2', 'T8', 'P4', 'AF3', 'F3', 'F8']
# Done:  s24
#
#
# ==========================================================================================
# Subject Name:  s24
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  11
# Channels selected in Growing Phase:  ['Pz', 'FC1', 'PO3', 'O1', 'P7', 'F8', 'FC2', 'CP5', 'F4', 'CP1', 'Fp2']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.825
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['O2', 'P8', 'FC5', 'CP1', 'F8', 'PO3', 'Fz', 'C3']
# Class Label:  all
# Accuracy in Growing Phase:  0.475
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['Pz', 'P3', 'T8', 'FC5', 'P7', 'T7', 'Oz', 'FC6']
# Done:  s25
#
#
# ==========================================================================================
# Subject Name:  s25
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.825
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['F4', 'FC5', 'C4']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  11
# Channels selected in Growing Phase:  ['F8', 'C4', 'F4', 'AF3', 'FC5', 'PO3', 'AF4', 'T7', 'Fp2', 'FC2', 'Pz']
# Class Label:  all
# Accuracy in Growing Phase:  0.575
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['F4', 'FC5', 'C4']
# Done:  s26
#
#
# ==========================================================================================
# Subject Name:  s26
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  1
# Channels selected in Growing Phase:  ['PO3']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  11
# Channels selected in Growing Phase:  ['CP5', 'AF4', 'F7', 'Oz', 'FC2', 'FC1', 'CP6', 'O1', 'Fp2', 'P7', 'T8']
# Class Label:  all
# Accuracy in Growing Phase:  0.55
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['Pz', 'P7', 'CP2', 'O1', 'FC6', 'CP6']
# Done:  s27
#
#
# ==========================================================================================
# Subject Name:  s27
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['Oz', 'PO3', 'F4', 'F3', 'CP6', 'T8']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  19
# Channels selected in Growing Phase:  ['PO3', 'Oz', 'P8', 'F4', 'F3', 'C4', 'Fz', 'AF3', 'F8', 'P4', 'Pz', 'PO4', 'CP2', 'Fp2', 'CP6', 'Cz', 'FC1', 'P3', 'Fp1']
# Class Label:  all
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  14
# Channels selected in Growing Phase:  ['Oz', 'P8', 'F3', 'T8', 'CP5', 'FC6', 'F4', 'CP2', 'CP6', 'F8', 'FC2', 'AF4', 'Cz', 'Fp1']
# Done:  s28
#
#
# ==========================================================================================
# Subject Name:  s28
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['FC6', 'C4', 'F7', 'P4', 'AF3', 'P3']
# Class Label:  arousal
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['PO3', 'CP6', 'CP2']
# Class Label:  all
# Accuracy in Growing Phase:  0.55
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['PO3', 'C4', 'Oz', 'CP2', 'CP6']
# Done:  s29
#
#
# ==========================================================================================
# Subject Name:  s29
# ==========================================================================================
# Class Label:  valence
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  16
# Channels selected in Growing Phase:  ['F8', 'AF3', 'PO4', 'Fp1', 'P4', 'FC1', 'P3', 'PO3', 'O1', 'C4', 'Cz', 'FC5', 'Fz', 'CP2', 'CP5', 'AF4']
# Class Label:  arousal
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-f1ff45ae2bea> in <module>
#      48         em_labels = emotion_label(labels, class_label) # get the emotion labels
#      49         channel_name = get_fisher_score(subject_name, em_labels) # get the fscore of all channels
# ---> 50         optimal_channel_name = growing_phase(channel_name) # get the optimal channels name
#
# <ipython-input-26-daf4f94d402c> in growing_phase(channel_name)
#     149         cur_cn = channel_name[i]
#     150         cn_list.append(cur_cn)
# --> 151         cur_acc = svmclassifier(cn_list, data.copy())
#     152         if(cur_acc<acc):
#     153             cn_list.remove(cur_cn)
#
# <ipython-input-26-daf4f94d402c> in svmclassifier(channel_name, data)
#     133         model = svm.SVC(kernel = 'poly')
#     134         model.fit(x_train, y_train)
# --> 135         pred_values = model.predict(x_test)
#     136         #pred_values = model.predict(x_test)
#     137         acc = accuracy_score(pred_values , y_test)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in predict(self, X)
#     622             y = np.argmax(self.decision_function(X), axis=1)
#     623         else:
# --> 624             y = super().predict(X)
#     625         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     626
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in predict(self, X)
#     340         y_pred : ndarray of shape (n_samples,)
#     341         """
# --> 342         X = self._validate_for_predict(X)
#     343         predict = self._sparse_predict if self._sparse else self._dense_predict
#     344         return predict(X)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in _validate_for_predict(self, X)
#     472
#     473         if not callable(self.kernel):
# --> 474             X = check_array(X, accept_sparse='csr', dtype=np.float64,
#     475                             order="C", accept_large_sparse=False)
#     476
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     506     dtypes_orig = None
#     507     has_pd_integer_array = False
# --> 508     if hasattr(array, "dtypes") and hasattr(array.dtypes, '__array__'):
#     509         # throw warning if columns are sparse. If all columns are sparse, then
#     510         # array.sparse exists and sparsity will be perserved (later).
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in dtypes(self)
#    5707         """
#    5708         data = self._mgr.get_dtypes()
# -> 5709         return self._constructor_sliced(data, index=self._info_axis, dtype=np.object_)
#    5710
#    5711     @final
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     364                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     365
# --> 366                 data = SingleBlockManager.from_array(data, index)
#     367
#     368         generic.NDFrame.__init__(self, data)
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in from_array(cls, array, index)
#    1580         Constructor for if we have an array that is not yet a Block.
#    1581         """
# -> 1582         block = make_block(array, placement=slice(0, len(index)), ndim=1)
#    1583         return cls(block, index)
#    1584
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2733     if klass is None:
#    2734         dtype = dtype or values.dtype
# -> 2735         klass = get_block_type(values, dtype)
#    2736
#    2737     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values.dtype):
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    2683     cls : class, subclass of Block
#    2684     """
# -> 2685     dtype = dtype or values.dtype
#    2686     vtype = dtype.type
#    2687
#
# KeyboardInterrupt:
