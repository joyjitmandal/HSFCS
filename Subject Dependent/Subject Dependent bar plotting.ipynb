# %% [markdown]
# # Valence

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=25)

# %%
import matplotlib.pyplot as plt
import numpy as np
#fig = plt.subplots(figsize =(12, 8))
labels = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19',\
          's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
all_channel = [52.5, 57.49, 65.0, 57.499, 72.5, 70.0, 70.0, 57.499, 62.5, 60.0, 32.5, 62.5, 80.0, 70.0, 52.5, 57.49, 45.0, 70.0, 70.0, 70.0, 50.0,\
               65.0, 60.0, 57.49, 70.0, 25.0, 72.5, 67.5, 55.00, 62.5, 52.5, 57.49]
# valence
opt_channel = [67.5, 67.5, 77.5, 67.5, 77.5, 80, 72.5, 67.5, 80, 67.5, 60, 72.5, 85, 80, 72.5, 65, 65, 80, 77.5, 75, 72.5, 67.5, 75, 57.5, 65, 72.5,\
               75, 70, 77.5, 67.5, 72.5, 67.5]
print(np.mean(np.array(all_channel)), np.mean(np.array(opt_channel)))
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize =(20, 10))
rects2 = ax.bar(x - width/2, all_channel, width, label = 'all channels')
rects1 = ax.bar(x + width/2, opt_channel, width, label = 'selected channels')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy', fontsize = 30)
ax.set_xlabel('Subjects', fontsize = 30)
ax.set_title('High/Low Valence', fontsize=30)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=85, fontsize=25)
ax.legend(fontsize=18)
ax.autoscale(tight=True, axis = "x")
plt.savefig("sub_dep_valence.pdf")
plt.show()
# Out:
# 60.3111875 71.796875

# %%
valence_opt = [['Fz', 'FC2', 'CP6', 'F7', 'FC1'], ['AF3', 'F4', 'F7', 'CP1', 'O1', 'Fz', 'FC6', 'CP5', 'T7', 'C4', 'Fp1', 'P3', 'Fp2'],
               ['O2', 'Oz', 'FC1'], ['O2', 'CP1', 'PO3'], ['C4', 'Cz', 'CP6', 'P7', 'FC6', 'FC2', 'O2', 'F4', 'F7', 'F3', 'Fp1', 'AF3', 'PO3', 'T7', 'AF4'],
                            ['P4', 'FC6', 'CP2', 'F4', 'O1', 'O2', 'Oz', 'Cz'], ['PO4', 'P4', 'T7', 'FC6', 'F4', 'FC5', 'F7', 'AF3'],
                            ['Fp1', 'P8', 'CP6', 'P7', 'AF3', 'O2', 'C4', 'Pz', 'T8', 'FC2', 'P3', 'AF4', 'PO3', 'Cz', 'CP5', 'Fz'], ['AF4', 'Oz', 'C4', 'F4'], 
                            ['P3', 'CP6', 'FC6'], ['P4', 'F4', 'P7', 'FC2'], ['CP1', 'F4', 'F3'], ['Cz', 'Fp2', 'Pz', 'AF3', 'FC2', 'P4', 'F7'], 
                            ['FC2', 'P3', 'F8', 'P8', 'FC5', 'AF4'], ['Pz', 'AF3'],
                            ['FC6', 'Fp1', 'Fp2', 'Cz', 'P4', 'P3', 'PO3', 'Oz', 'C4', 'CP2', 'F3', 'CP1', 'O1', 'P8', 'T8', 'C3', 'PO4', 'Pz', 'Fz', 'F8', 'FC2', 'CP6', 'F4', 'P7'],
                            ['F8', 'P3', 'PO3', 'CP1'], ['FC6', 'AF4', 'FC1', 'Pz', 'Oz', 'C3', 'F8', 'CP1', 'T7', 'Cz', 'PO4', 'Fp1', 'F7'],
                            ['C4', 'F3', 'CP6', 'FC6'], ['AF4'], ['AF3', 'P3', 'F4', 'PO4', 'Oz', 'CP2', 'AF4', 'T8'],
                            ['C3', 'T8', 'P4', 'PO3', 'Fp2', 'AF4', 'C4', 'Fp1', 'F4', 'AF3', 'CP5', 'FC2', 'FC5', 'FC1', 'Oz'],
                            ['T8', 'P4', 'F4', 'AF3'], ['FC1', 'Pz', 'PO3'], ['FC2', 'Fp2'], ['Pz', 'P3', 'FC2', 'FC1', 'P7', 'T7'],
                            ['Oz', 'FC5', 'CP6', 'O2', 'C4', 'CP2', 'FC6', 'F3', 'C3', 'P3', 'CP5', 'P4', 'PO4', 'Cz', 'FC1', 'Pz', 'O1', 'Fz', 'T7', 'FC2', 'P7', 'Fp2'],
                            ['C3', 'CP2', 'F3', 'O1', 'CP1', 'Pz', 'Oz', 'PO4', 'O2', 'P4', 'P8', 'CP5'], ['AF3', 'Cz', 'CP6', 'P4', 'Fp1', 'F8', 'F3', 'P7', 'FC6', 'F4', 'AF4'],
                            ['PO4', 'Fz', 'Cz', 'AF3', 'FC2', 'Oz', 'P4', 'FC1', 'Fp2', 'O1', 'O2', 'Fp1', 'C3', 'T7'], ['CP6', 'CP2', 'Cz', 'CP5'],
                            ['CP2', 'O1', 'O2', 'CP6', 'CP5', 'PO4', 'FC6', 'P8', 'FC1', 'AF3', 'Cz', 'Oz', 'FC1']]

# %%
no_valence = []
for i in valence_opt:
  no_valence.append(len(i))

# %%
no_valence

# %% [markdown]
# # Arousal

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
#fig = plt.subplots(figsize =(12, 8))
labels = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19',\
          's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
all_channel = [57.49, 42.5, 75.0, 60.0, 17.5, 47.5, 60.0, 52.5, 55.00, 60.0, 67.5, 75.0, 70.0, 67.5, 60.0, 62.5, 77.5, 67.5, 67.5, 77.5, 72.5,\
               60.0, 75.0, 82.5, 62.5, 70.0, 60.0, 57.49, 60.0, 65.0, 62.5, 52.5]
# valence
opt_channel = [75, 57.5, 80, 65, 30, 60, 72.5, 65, 77.5, 67.5, 72.5, 85, 87.5, 75, 77.5, 77.5,\
               82.5, 70, 72.5, 85, 85, 70, 85, 82.5, 72.5, 70, 65, 70, 72.5, 65, 75, 70]
print(np.mean(np.array(all_channel)), np.mean(np.array(opt_channel)))
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize =(20, 10))
rects1 = ax.bar(x - width/2, all_channel, width, label = 'all channels')
rects2 = ax.bar(x + width/2, opt_channel, width, label = 'selected channels')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy', fontsize = 30)
ax.set_xlabel('Subjects', fontsize = 30)
ax.set_title('High/Low Arousal', fontsize = 30)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=85, fontsize=25)
ax.legend(fontsize=18)
ax.autoscale(tight=True, axis = "x")
#fig.tight_layout(pad=1.08, h_pad=None, w_pad=0.1, rect=None)
plt.savefig("sub_dep_arousal.pdf")
plt.show()
# Out:
# 62.499375 72.421875

# %%
arousal_opt = [['P7', 'CP1', 'P3', 'Fz', 'P8', 'FC2', 'F7', 'C4'], ['FC2'],
                            ['AF4', 'FC1', 'O2', 'F3', 'AF3', 'P8', 'T7', 'C4', 'Pz', 'FC5', 'PO3'], ['P8', 'CP2', 'P7', 'Pz', 'P3'], ['Fz', 'P7', 'T7', 'CP6', 'O2', 'Fp1'], 
                            ['C3', 'AF4', 'AF3', 'P7', 'F3', 'F4', 'CP5', 'T8', 'Oz', 'FC6', 'F7', 'Cz'], ['FC1', 'F3', 'O1', 'FC5', 'P3', 'Fz'], ['T8', 'Fp1', 'FC6', 'Fp2', 'Fz', 'CP2', 'PO3', 'CP1', 'Cz'], ['AF4'],
                            ['FC1', 'Fp1', 'CP5', 'P7', 'T8', 'PO4', 'C3', 'PO3', 'F4', 'Cz'], ['T7'], ['FC6', 'CP5', 'F3', 'Cz', 'FC2'], ['PO3', 'P7', 'Fp2'], ['PO3', 'FC2', 'P3', 'AF3', 'CP5', 'Pz', 'F7', 'T7', 'O2', 'F3'],
                            ['FC2', 'FC1', 'Fz', 'P3', 'AF4', 'Cz', 'CP1', 'CP2', 'Fp2', 'AF3', 'CP5', 'Pz'], ['O2', 'FC1', 'C3', 'C4', 'Cz'], ['P4', 'CP2', 'FC2', 'Fp1'], ['AF4', 'FC6', 'FC5', 'PO4', 'P3', 'CP1'], 
                            ['CP5', 'P8', 'C4', 'FC6', 'PO4', 'O2', 'P4', 'CP6', 'P7', 'CP2', 'PO3', 'FC2'], ['F3', 'P7', 'CP6', 'F4', 'FC6', 'F8', 'CP5', 'Fz', 'T7',  'FC5', 'AF3', 'O1', 'CP1', 'Cz', 'F7', 'C3', 'FC1'], 
                            ['P4', 'Fz'], ['O1', 'CP2', 'FC1', 'CP1', 'CP6', 'F8', 'P8'], ['Fp1', 'F3', 'CP5', 'Cz', 'FC5'],
                            ['Pz', 'O2', 'P8', 'CP2', 'O1', 'PO3', 'F8', 'FC1', 'P3', 'CP1', 'Cz', 'T8', 'FC2', 'C3', 'FC5', 'Fz', 'CP5', 'F4', 'PO4', 'F7', 'Oz', 'T7', 'P7', 'AF4', 'Fp2', 'FC6', 'F3', 'P4', 'Fp1', 'AF3', 'C4', 'CP6'],
                            ['FC2'], ['AF4', 'FC5', 'CP5', 'Oz', 'FC2', 'C3', 'Cz'], ['PO3', 'Oz', 'AF4', 'CP6', 'F8', 'Cz', 'FC6', 'O1', 'P8', 'F4', 'Fp2'],
                            ['PO3', 'F4', 'FC6', 'Oz', 'CP2', 'O2', 'P4', 'CP6'], ['O2', 'CP6', 'Cz', 'PO4', 'O1', 'FC1', 'T8', 'P4', 'F4', 'C3'],
                            ['Oz', 'P4', 'CP1', 'P3', 'FC6', 'AF3', 'F3', 'F7', 'CP2', 'Cz', 'CP5', 'C4', 'FC1', 'P8', 'T8', 'T7', 'F8', 'C3', 'O2', 'CP6', 'Fp1', 'AF4', 'O1', 'F4'],
                            ['FC2', 'C4', 'PO4', 'P4', 'F4', 'FC1', 'C3', 'CP6', 'AF3', 'F7', 'FC5'], ['Fz', 'Cz', 'P7', 'F4', 'F8', 'C4', 'P4']]

# %%
no_arousal = []
for i in arousal_opt:
  no_arousal.append(len(i))

# %%
print(no_arousal)
# Out:
# [8, 1, 11, 5, 6, 12, 6, 9, 1, 10, 1, 5, 3, 10, 12, 5, 4, 6, 12, 17, 2, 7, 5, 32, 1, 7, 11, 8, 10, 24, 11, 7]

# %% [markdown]
# # Four Class

# %%
all_opt = [['P7', 'P8', 'Fz', 'CP6', 'PO3', 'FC5', 'FC1'], ['AF3', 'CP1', 'F7', 'O1', 'AF4', 'FC6'],
                        ['O2', 'Oz', 'O1'], ['P8', 'CP2', 'Cz'], ['Fz', 'O2', 'PO4', 'FC1', 'F7', 'Oz', 'CP6', 'Fp2', 'FC6', 'C4', 'Pz', 'CP5', 'O1', 'T8'],
                        ['CP1', 'T7', 'FC6', 'AF3'], ['PO4', 'Pz', 'Fp2', 'Cz', 'P8', 'P7', 'O1', 'FC2', 'CP2'], ['Fp1', 'CP6', 'O2', 'C4', 'T8', 'AF3', 'PO3'],
                        ['T7', 'AF4', 'T8', 'P8', 'Cz'], ['T7', 'P3', 'FC1', 'CP1', 'Cz', 'PO3', 'CP2', 'O1'], ['C3', 'P7', 'FC2', 'F4', 'CP2', 'P3', 'F8', 'FC6', 'F7', 'FC5', 'FC1', 'F3', 'CP5', 'CP1'],
                        ['Cz', 'P3', 'F3', 'AF3'], ['Cz', 'AF3', 'Pz', 'Fp2', 'Oz', 'P4', 'Fz', 'FC2', 'AF4', 'P8', 'F8', 'P7', 'CP1'], ['FC2', 'PO3', 'P7'],
                        ['Pz', 'FC6', 'P4', 'Fp1', 'PO3', 'AF3'], ['O2', 'FC1', 'T8'], ['CP1', 'CP6', 'T8', 'AF4', 'PO4', 'O2', 'Pz', 'O1', 'F4', 'C4'],
                        ['FC6', 'AF4', 'Pz', 'F8', 'O1'], ['P8', 'CP6', 'T8', 'F4'], ['AF4', 'Fz', 'PO3', 'FC2', 'CP5', 'F8', 'P4', 'T7', 'F7', 'Fp2', 'FC5', 'PO4', 'C3'],
                        ['P7', 'T8', 'P4', 'Fz', 'F8', 'Fp2'], ['O2', 'C3', 'P4', 'PO4', 'F3', 'PO3', 'Fz', 'Fp2', 'AF4', 'T8', 'Fp1', 'CP1'],
                        ['T7', 'Fp1', 'CP5', 'P8', 'F7', 'F8', 'AF4', 'FC2'], ['Pz', 'P8', 'CP2', 'O1', 'P3', 'CP1', 'Cz', 'C3', 'FC2', 'T7', 'Oz', 'P7', 'AF4', 'Fp2', 'FC6', 'F3', 'P4', 'Fp1', 'C4', 'AF3', 'CP6'],
                        ['FC2', 'FC5', 'F4'], ['P3', 'FC5'], ['Oz', 'T8', 'AF4', 'FC5', 'CP6', 'FC6', 'CP5', 'O2', 'CP1', 'F7', 'C4', 'F3', 'CP2', 'C3', 'P4', 'F8', 'T7', 'Cz', 'Fz'],
                        ['CP2', 'C3', 'Oz', 'FC1', 'Pz', 'O2', 'PO4', 'P4', 'Fz', 'P8', 'CP5', 'PO3', 'Fp1', 'FC6', 'AF4', 'Fp2', 'C4', 'CP6'],
                        ['AF3', 'CP6', 'O2', 'F8', 'O1', 'CP1', 'CP5'], ['Oz', 'PO4'], ['C4', 'F4'], ['CP6', 'CP2', 'CP5', 'O1', 'PO4', 'Fz', 'AF4', 'Cz', 'Oz']]

# %%
no_all = []
for i in all_opt:
  no_all.append(len(i))

# %%
print(no_all)
# Out:
# [7, 6, 3, 3, 14, 4, 9, 7, 5, 8, 14, 4, 13, 3, 6, 3, 10, 5, 4, 13, 6, 12, 8, 21, 3, 2, 19, 18, 7, 2, 2, 9]

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
#fig = plt.subplots(figsize =(12, 8))
labels = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19',\
          's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
all_channel = [20.0, 37.5, 42.5, 42.5, 22.5, 32.5, 32.5, 30.0, 32.5, 35.0, 40.0, 47.5, 55.00, 50.0, 27.50, 27.50, 40.0, 32.5, 27.50, 55.00, 30.0,\
               40.0, 50.0, 47.5, 35.0, 47.5, 57.49, 37.5, 45.0, 15.0, 42.5, 27.50]
# valence
opt_channel = [52.5, 52.5, 55, 47.5, 30, 42.5, 45, 42.5, 55, 40, 50, 67.5, 72.5, 60, 40, 57.5, 50, 55, 40, 67.5, 45, 47.5, 57.5, 50, 52.5, 57.5,\
               60, 45, 55, 30, 52.5, 42.5]
print(np.mean(np.array(all_channel)), np.mean(np.array(opt_channel)))
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize =(20, 10))
rects1 = ax.bar(x - width/2, all_channel, width, label = 'all channels')
rects2 = ax.bar(x + width/2, opt_channel, width, label = 'selected channels')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy', fontsize = 30)
ax.set_xlabel('Subjects', fontsize= 30)
ax.set_title('HVHA/HVLA/LVLA/LVHA', fontsize=30)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=85, fontsize=25)
ax.legend(fontsize=18)
ax.autoscale(tight=True, axis = "x")
plt.savefig("sub_dep_four.pdf")
plt.show()
# Out:
# 37.6559375 50.546875

# %%
"""
Four class
"""
S-01 & P7, P8, Fz, CP6, PO3, FC5, FC1 & 52.5\\
S-02 & AF3, CP1, F7, O1, AF4, FC6 & 52.5\\
S-03 & O2, Oz, O1 & 55\\
S-04 & P8, CP2, Cz & 47.5\\
S-05 & Fz, O2, PO4, FC1, F7, Oz, CP6, Fp2, FC6, C4, Pz, CP5, O1, T8 & 30\\ 
S-06 & CP1, T7, FC6, AF3 & 42.5\\
S-07 & PO4, Pz, Fp2, Cz, P8, P7, O1, FC2, CP2 & 45\\
S-08 & Fp1, CP6, O2, C4, T8, AF3, PO3 & 42.5\\
S-09 & T7, AF4, T8, P8, Cz & 55\\
S-10 & T7, P3, FC1, CP1, Cz, PO3, CP2, O1 & 40\\
S-11 & C3, P7, FC2, F4, CP2, P3, F8, FC6, F7, FC5, FC1, F3, CP5, CP1 & 50\\
S-12 & Cz, P3, F3, AF3 & 67.5\\
S-13 & Cz, AF3, Pz, Fp2, Oz, P4, Fz, FC2, AF4, P8, F8, P7, CP1 & 72.5\\
S-14 & FC2, PO3, P7 & 60\\
S-15 & Pz, FC6, P4, Fp1, PO3, AF3 & 40\\
S-16 & O2, FC1, T8 & 57.5\\
S-17 & CP1, CP6, T8, AF4, PO4, O2, Pz, O1, F4, C4 & 50\\
S-18 & FC6, AF4, Pz, F8, O1 & 55\\
S-19 & P8, CP6, T8, F4 & 40\\
S-20 & AF4, Fz, PO3, FC2, CP5, F8, P4, T7, F7, Fp2, FC5, PO4, C3 & 67.5\\
S-21 & P7, T8, P4, Fz, F8, Fp2 & 45\\
S-22 & O2, C3, P4, PO4, F3, PO3, Fz, Fp2, AF4, T8, Fp1, CP1 & 47.5\\
S-23 & T7, Fp1, CP5, P8, F7, F8, AF4, FC2 & 57.5\\
S-24 & Pz, P8, CP2, O1, P3, CP1, Cz, C3, FC2, T7, Oz, P7, AF4, Fp2, FC6, F3, P4, Fp1, C4, AF3, CP6 & 50\\
S-25 & FC2, FC5, F4 & 52.5\\
S-26 & P3, FC5 & 57.5\\
S-27 & Oz, T8, AF4, FC5, CP6, FC6, CP5, O2, CP1, F7, C4, F3, CP2, C3, P4, F8, T7, Cz, Fz & 60\\
S-28 & CP2, C3, Oz, FC1, Pz, O2, PO4, P4, Fz, P8, CP5, PO3, Fp1, FC6, AF4, Fp2, C4, CP6 & 45\\
S-29 & AF3, CP6, O2, F8, O1, CP1, CP5 & 55\\
S-30 & Oz, PO4 & 30\\
S-31 & C4, F4 & 52.5\\
S-32 & CP6, CP2, CP5, O1, PO4, Fz, AF4, Cz, Oz & 42.5\\

"""
Four class
"""
[52.5, 52.5, 55, 47.5, 30, 42.5, 45, 42.5, 55, 40, 50, 67.5, 72.5, 60, 40, 57.5, 50, 55, 40, 67.5, 45, 47.5, 57.5, 50, 52.5, 57.5, 60, 45, 55, 30,\
 52.5, 42.5]

# %%
"""
Valence
"""
S-01 & Fz, FC2, CP6, F7, FC1 & 67.5\\
S-02 & AF3, F4, F7, CP1, O1, Fz, FC6, CP5, T7, C4, Fp1, P3, Fp2 & 67.5\\
S-03 & O2, Oz, FC1 & 77.5\\
S-04 & O2, CP1, PO3 & 67.5\\
S-05 & C4, Cz, CP6, P7, FC6, FC2, O2, F4, F7, F3, Fp1, AF3, PO3, T7, AF4 & 77.5\\ 
S-06 & P4, FC6, CP2, F4, O1, O2, Oz, Cz & 80\\
S-07 & PO4, P4, T7, FC6, F4, FC5, F7, AF3 & 72.5\\
S-08 & Fp1, P8, CP6, P7, AF3, O2, C4, Pz, T8, FC2, P3, AF4, PO3, Cz, CP5, Fz & 67.5\\
S-09 & AF4, Oz, C4, F4 & 80\\
S-10 & P3, CP6, FC6 & 67.5\\
S-11 & P4, F4, P7, FC2 & 60\\
S-12 & CP1, F4, F3 & 72.5\\
S-13 & Cz, Fp2, Pz, AF3, FC2, P4, F7 & 85\\
S-14 & FC2, P3, F8, P8, FC5, AF4 & 80\\
S-15 & Pz, AF3 & 72.5\\
S-16 & FC6, Fp1, Fp2, Cz, P4, P3, PO3, Oz, C4, CP2, F3, CP1, o1, P8, T8,\\
         & C3, PO4, Pz, Fz, F8, FC2, CP6, F4, P7 & 65\\
S-17 & F8, P3, PO3, CP1 & 65\\
S-18 & FC6, AF4, FC1, Pz, Oz, C3, F8, CP1, T7, Cz, PO4, Fp1, F7 & 80\\
S-19 & C4, F3, CP6, FC6 & 77.5\\
S-20 & AF4 & 75\\
S-21 & AF3, P3, F4, PO4, Oz, CP2, AF4, T8 & 72.5\\
S-22 & C3, T8, P4, PO3, Fp2, AF4, C4, Fp1, F4, AF3, CP5, FC2, FC5, FC1, Oz & 67.5\\
S-23 & T8, P4, F4, AF3 & 75\\
S-24 & FC1, Pz, PO3 & 57.5\\
S-25 & FC2, Fp2 & 65\\
S-26 & Pz, P3, FC2, FC1, P7, T7 & 72.5\\
S-27 & Oz, FC5, CP6, O2, C4, CP2, FC6, F3, C3, P3, CP5, P4, PO4,\\
& Cz, FC1, Pz, O1, Fz, T7, FC2, P7, Fp2 & 75\\
S-28 & C3, CP2, F3, O1, CP1, Pz, Oz, PO4, O2, P4, P8, CP5 & 70\\
S-29 & AF3, Cz, CP6, P4, Fp1, F8, F3, P7, FC6, F4, AF4 & 77.5\\
S-30 & PO4, Fz, Cz, AF3, FC2, Oz, P4, FC1, Fp2, O1, O2, Fp1, C3, T7 & 67.5\\
S-31 & PO4, Fz, Cz, AF3, FC2, Oz, P4, FC1, Fp2, O1, O2, Fp1, C3, T7 & 72.5\\
S-32 & CP2, O1, O2, CP6, CP5, PO4, FC6, P8, FC1, AF3, Cz, Oz, FC1 & 67.5\\

# acc = [67.5, 67.5, 77.5, 67.5, 77.5, 80, 72.5, 67.5, 80, 67.5, 60, 2.5, 85, 80, 72.5, 65, 65, 80, 77.5, 75, 72.5, 67.5, 75, 57.5, 65, 72.5, 75, 70,\
          77.5, 67.5, 72.5, 67.5]

# %%
"""
Arousal
"""
S-01 & P7, CP1, P3, Fz, P8, FC2, F7, C4 & 75\\
S-02 & FC2 & 57.5\\
S-03 & AF4, FC1, O2, F3, AF3, P8, T7, C4, Pz, FC5, PO3 & 80\\
S-04 & P8, CP2, P7, Pz, P3 & 65\\
S-05 & Fz, P7, T7, CP6, O2, Fp1 & 30\\ 
S-06 & C3, AF4, AF3, P7, F3, F4, CP5, T8, Oz, FC6, F7, Cz & 60\\
S-07 & FC1, F3, O1, FC5, P3, Fz & 72.5\\
S-08 & T8, Fp1, FC6, Fp2, Fz, CP2, PO3, CP1, Cz & 65\\
S-09 & AF4 & 77.5\\
S-10 & FC1, Fp1, CP5, P7, T8, PO4, C3, PO3, F4, Cz & 67.5\\
S-11 & T7 & 72.5\\
S-12 & FC6, CP5, F3, Cz, FC2 & 85\\
S-13 & PO3, P7, Fp2 & 87.5\\
S-14 & PO3, FC2, P3, AF3, CP5, Pz, F7, T7, O2, F3 & 75\\
S-15 & FC2, FC1, Fz, P3, AF4, Cz, CP1, CP2, Fp2, AF3, CP5, Pz & 77.5\\
S-16 & O2, FC1, C3, C4, Cz & 77.5\\
S-17 & P4, CP2, FC2, Fp1 & 82.5\\
S-18 & AF4, FC6, FC5, PO4, P3, CP1 & 70\\
S-19 & CP5, P8, C4, FC6, PO4, O2, P4, CP6, P7, CP2, PO3, FC2 & 72.5\\
S-20 & F3, P7, CP6, F4, FC6, F8, CP5, Fz, T7, FC5, AF3, O1, CP1, Cz, F7, C3, FC1 & 85\\
S-21 & P4, Fz & 85\\
S-22 & O1, CP2, FC1, CP1, CP6, F8, P8 & 70\\
S-23 & Fp1, F3, CP5, Cz, FC5 & 85\\
S-24 & Pz, O2, P8, CP2, O1, PO3, F8, FC1, P3, CP1, Cz, T8, FC2, C3, FC5, Fz, CP5,\\
    & F4, PO4, F7, Oz, T7, P7, AF4, Fp2, FC6, F3, P4, Fp1, AF3, C4, CP6 & 82.5\\
S-25 & FC2 & 72.5\\
S-26 & AF4, FC5, CP5, Oz, FC2, C3, Cz & 70\\
S-27 & PO3, Oz, AF4, CP6, F8, Cz, FC6, O1, P8, F4, Fp2 & 65\\
S-28 & PO3, F4, FC6, Oz, CP2, O2, P4, CP6 & 70\\
S-29 & O2, CP6, Cz, PO4, O1, FC1, T8, P4, F4, C3 & 72.5\\
S-30 & Oz, P4, CP1, P3, FC6, AF3, F3, F7, CP2, Cz, CP5, C4, FC1, P8,\\
    & T8, T7, F8, C3, O2, CP6, Fp1, AF4, O1, F4 & 65\\
S-31 & FC2, C4, PO4, P4, F4, FC1, C3, CP6, AF3, F7, FC5 & 75\\
S-32 & Fz, Cz, P7, F4, F8, C4, P4 & 70\\

# %%
"""
Arousal
"""
[75, 57.5, 80, 65, 30, 60, 72.5, 65, 77.5, 67.5, 72.5, 85, 87.5, 75, 77.5, 77.5,\
 82.5, 70, 72.5, 85, 85, 70, 85, 82.5, 72.5, 70, 65, 70, 72.5, 65, 75, 70]

# %%
def autolabel(rects):
    #Attach a text label above each bar in *rects*, displaying its height.
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


#autolabel(rects1)
#autolabel(rects2)
