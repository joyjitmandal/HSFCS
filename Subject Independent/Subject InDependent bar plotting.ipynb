# %% [markdown]
# # Valence

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=25)

# %%
import matplotlib.pyplot as plt
import numpy as np
#fig = plt.subplots(figsize =(12, 8))
labels = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19',\
          's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
all_channel = [57.5, 52.5, 17.5, 65.0, 60.0, 72.5, 55, 47.5, 10.0, 55, 70.0, 65.0, 65.0, 57.5,\
               52.5, 65.0, 50.0, 60.0, 37.5, 57.5, 25, 55, 62.5, 52.5, 52.5, 65.0, 72.5, 42.5, 65.0, 67.5, 60.0, 67.5]
# valence
opt_channel = [60.0, 52.5, 17.5, 65, 60.0, 72.5, 55, 47.5, 52.5, 55, 70, 65.0, 65, 57.5,\
               52.5, 67.5, 50.0, 67.5, 37.5, 60.0, 50, 55, 67.5, 52.5, 52.5, 65.0, 75.0, 42.5, 65.0, 67.5, 60.0, 67.5]

print(np.mean(np.array(all_channel)), np.mean(np.array(opt_channel)))
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize =(20, 10))
rects1 = ax.bar(x - width/2, all_channel, width, label = 'all channels')
rects2 = ax.bar(x + width/2, opt_channel, width, label = 'selected 10 channels')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy', fontsize = 30)
ax.set_xlabel('Subjects', fontsize = 30)
ax.set_title('High/Low Valence', fontsize=30)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=85, fontsize=25)
ax.legend(fontsize=18)
ax.autoscale(tight=True, axis = "x")
plt.ylim([0, 87])
plt.savefig("sub_indep_valence.pdf")
plt.show()
# Out:
# 55.0 57.8125

# %% [markdown]
# # Arousal

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
#fig = plt.subplots(figsize =(12, 8))
labels = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19',\
          's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
all_channel = [57.5, 60.0, 80.0, 57.5, 12.5, 55, 65.0, 52.5, 60.0, 65.0, 60.0, 82.5, 85.0, 67.5, 57.5, 42.5, 65.0, 60.0, 67.5, 77.5, 80.0, 60.0, 75.0,\
               82.5, 70.0, 60.0, 65.0, 52.5, 62.5, 62.5, 62.5, 67.5]
# valence
opt_channel = [65.0, 60.0, 80.0, 57.5, 12.5, 55, 70.0, 52.5, 60.0, 65.0, 62.5, 82.5, 85.0, 67.5, 57.5, 50.0, 65.0, 60.0, 65.0, 77.5, 80.0, 60.0, 75,\
               82.5, 72.5, 60.0, 67.5, 55, 62.5, 62.5, 62.5, 67.5]
print(np.mean(np.array(all_channel)), np.mean(np.array(opt_channel)))
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize =(20, 10))
rects1 = ax.bar(x - width/2, all_channel, width, label = 'all channels')
rects2 = ax.bar(x + width/2, opt_channel, width, label = 'selected 8 channels')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy', fontsize = 30)
ax.set_xlabel('Subjects', fontsize = 30)
ax.set_title('High/Low Arousal', fontsize=30)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=85, fontsize=25)
ax.legend(fontsize=18)
ax.autoscale(tight=True, axis = "x")
plt.savefig("sub_indep_arousal.pdf")
plt.show()
# Out:
# 63.4375 64.296875

# %% [markdown]
# # Four Class

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
#fig = plt.subplots(figsize =(12, 8))
labels = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19',\
          's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
all_channel = [27.5, 37.5, 52.5, 50.0, 27.5, 40.0, 37.5, 27.5, 37.5, 20.0, 47.5, 47.5, 52.5, 35.0, 30.0, 15.0, 20.0, 40.0, 45.0, 25.0, 45.0, 10.0, 37.5,\
               45.0, 37.5, 42.5, 57.5, 35.0, 37.5, 15.0, 47.5, 42.5]

# valence
opt_channel = [32.5, 37.5, 52.5, 50.0, 32.5, 40.0, 37.5, 27.5, 37.5, 20.0, 47.5, 50.0, 52.5, 35.0, 30.0, 17.5, 20.0, 40.0, 45.0, 35.0, 45.0, 5.0, 37.5,\
               45.0, 37.5, 42.5, 60.0, 35.0, 45.0, 17.5, 47.5, 42.5]
print(np.mean(np.array(all_channel)), np.mean(np.array(opt_channel)))
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize =(20, 10))
rects1 = ax.bar(x - width/2, all_channel, width, label = 'all channels')
rects2 = ax.bar(x + width/2, opt_channel, width, label = 'selected 7 channels')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy', fontsize = 30)
ax.set_xlabel('Subjects', fontsize = 30)
ax.set_title('HVHA/HVLA/LVLA/LVHA', fontsize=30)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=85, fontsize=25)
ax.legend(fontsize=18)
ax.autoscale(tight=True, axis = "x")
plt.ylim([0, 75])
plt.savefig("sub_indep_four.pdf")
plt.show()
# Out:
# 36.484375 37.5

# %%
6/32
# Out:
# 0.1875
