# %% [markdown]
# # Valence

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
matplotlib.rc('xtick', labelsize = 20) 
matplotlib.rc('ytick', labelsize = 25)
labels = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14',
          's15', 's16', 's17', 's18', 's19', 's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28',
          's29', 's30', 's31', 's32']
all_channel = [45.0, 67.5, 67.5, 52.5, 62.5, 75.0, 60.0, 52.5, 75.0, 62.5, 57.5, 55.0, 60.0, 62.5, 67.5, 65.0, 50.0,\
               77.5, 65.0, 72.5, 15.0, 60.0, 72.5, 55.0, 75.0, 50.0, 75.0, 62.5, 75.0, 60.0, 62.5, 62.5]
# valence
opt_channel = [47.5, 65.0, 65.0, 60.0, 55, 70.0, 65.0, 60.0, 72.5, 62.5, 57.5, 62.5, 65.0, 60.0, 62.5, 70.0,
               40.0, 87.5, 75.0, 67.5, 15.0, 62.5, 57.5, 52.5, 70.0, 60.0, 75.0, 20.0, 65.0, 65.0, 50.0, 60.0]

print(np.mean(np.array(all_channel)), np.mean(np.array(opt_channel)))
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize =(20, 10))
rects1 = ax.bar(x - width/2, all_channel, width, label = 'all channels')
rects2 = ax.bar(x + width/2, opt_channel, width, label = 'selected 7 channels')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy', fontsize = 30)
ax.set_xlabel('Subjects', fontsize = 30)
ax.set_title('High/Low Valence', fontsize=30)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=85, fontsize=25)
ax.legend(fontsize=18)
ax.autoscale(tight=True, axis = "x")
plt.ylim([0, 90])
plt.savefig("sub_indep_valence.pdf")
plt.show()
# Out:
# 61.796875 60.078125

# %% [markdown]
# # Arousal

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
#fig = plt.subplots(figsize =(12, 8))
labels = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19',\
          's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
all_channel = [60.0, 55.0, 70.0, 55.0, 45.0, 50.0, 47.5, 60.0, 60.0, 50.0, 60.0, 82.5, 75.0, 65.0, 60.0, 67.5, 70.0,\
               67.5, 60.0, 75.0, 77.5, 40.0, 70.0, 80.0, 75.0, 57.5, 70.0, 40.0, 72.5, 67.5, 57.5, 57.5]
# valence
opt_channel = [57.5, 50.0, 77.5, 55.0, 47.5, 57.5, 57.5, 57.5, 45.0, 52.5, 57.5, 75.0, 75.0, 62.5, 57.5, 57.5, 75.0,\
               52.5, 57.5, 75.0, 80.0, 40.0, 75.0, 80.0, 72.5, 50.0, 75.0, 47.5, 77.5, 60.0, 67.5, 52.5]
print(np.mean(np.array(all_channel)), np.mean(np.array(opt_channel)))
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize = (20, 10))
rects1 = ax.bar(x - width/2, all_channel, width, label = 'all channels')
rects2 = ax.bar(x + width/2, opt_channel, width, label = 'selected 11 channels')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy', fontsize = 30)
ax.set_xlabel('Subjects', fontsize = 30)
ax.set_title('High/Low Arousal', fontsize=30)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=85, fontsize=25)
ax.legend(fontsize=18)
ax.autoscale(tight=True, axis = "x")
plt.ylim([0, 90])
plt.savefig("sub_indep_arousal.pdf")
plt.show()
# Out:
# 62.5 61.875

# %% [markdown]
# # Four Class

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
#fig = plt.subplots(figsize =(12, 8))
labels = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19',\
          's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']
all_channel = [27.5, 45.0, 40.0, 42.5, 10.0, 37.5, 30.0, 32.5, 40.0, 30.0, 17.5, 47.5, 32.5, 42.5, 47.5, 37.5,\
               27.5, 32.5, 22.5, 52.5, 37.5, 22.5, 42.5, 30.0, 52.5, 42.5, 60.0, 17.5, 45.0, 17.5, 45.0, 25.0]
# valence
opt_channel = [32.5, 42.5, 62.5, 45.0, 15.0, 35.0, 32.5, 32.5, 37.5, 27.5, 35.0, 52.5, 30.0, 45.0, 42.5, 40.0, 37.5,\
               35.0, 17.5, 47.5, 47.5, 30.0, 45.0, 47.5, 55.0, 47.5, 55.0, 37.5, 50.0, 15.0, 37.5, 27.5]
print(np.mean(np.array(all_channel)), np.mean(np.array(opt_channel)))
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize =(20, 10))
rects1 = ax.bar(x - width/2, all_channel, width, label = 'all channels')
rects2 = ax.bar(x + width/2, opt_channel, width, label = 'selected 7 channels')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy', fontsize = 30)
ax.set_xlabel('Subjects', fontsize = 30)
ax.set_title('HVHA/HVLA/LVLA/LVHA', fontsize=30)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=85, fontsize=25)
ax.legend(fontsize=18)
ax.autoscale(tight=True, axis = "x")
plt.ylim([0, 70])
plt.savefig("sub_indep_four.pdf")
plt.show()
# Out:
# 35.390625 38.75

# %% [markdown]
# # Result Ananlysis

# %%
[[97.5 , 100  , 96.7 , 98.0 && 92.5, 96.7 , 94.2 , 94.6 && 72.5  , 70.8 , 60.0 , 62.9],
[87.5 , 85.0 , 93.3 , 86.0 && 87.5, 93.3 , 90.0 , 90.7 && 65.0  , 59.2 , 47.8 , 51.0],
[82.5 , 85.0 , 85.0 , 82.3 && 85.0, 95.0 , 81.7 , 86.0 && 75.0  , 69.6 , 64.3 , 65.4],
[85.0 , 80.0 , 91.7 , 83.0 && 87.5, 90.0 , 88.4 , 86.0 && 72.5 	, 63.7 , 53.7 , 57.3],
[92.5 , 91.7 , 96.7 , 92.7 && 82.5, 90.0 , 83.3 , 84.3 && 62.5 	, 60.0 , 48.7 , 52.1], 
[87.5 , 100  , 87.5 , 92.9 && 77.5, 77.5 , 82.5 , 77.8 && 67.5 	, 62.5 , 53.7 , 56.5],
[82.5 , 90.0 , 88.3 , 87.8 && 80.0, 88.3 , 83.3 , 83.1 && 70.0 	, 60.0 , 53.2 , 55.5],
[92.5 , 1.0  , 90.8 , 94.6 && 72.5, 84.2 , 73.3 , 76.7 && 62.5 	, 55.0 , 47.5 , 50.0],
[85.0 , 95.0 , 83.3 , 87.7 && 77.5, 85.0 , 83.3 , 82.0 && 62.5 	, 61.7 , 51.5 , 54.8],
[95.0 , 95.0 , 96.7 , 94.7 && 85.0, 86.7 , 90.8 , 85.9 && 85.0 	, 85.0 , 77.5 , 80.0],
[90.0 , 91.7 , 91.7 , 91.0 && 82.5, 85.0 , 81.7 , 81.3 && 67.5 	, 63.3 , 52.1 , 55.3],
[85.0 , 78.3 , 96.7 , 83.0 && 92.5, 100  , 92.5 , 95.7 && 82.5 	, 77.5 , 73.3 , 73.3],
[90.0 , 85.0 , 95.0 , 86.7 && 92.5, 100  , 92.5 , 95.7 && 72.5 	, 70.0 , 61.7 , 63.0],
[87.5 , 80.0 , 96.7 , 84.7 && 95.0, 96.7 , 96.7 , 96.0 && 62.5 	, 59.6 , 50.8 , 52.4],
[97.5 , 95.0 , 100  , 96.7 && 90.0, 85.0 , 95.0 , 88.3 && 67.5 	, 67.5 , 57.5 , 60.3],
[92.5 , 90.0 , 95.0 , 90.0 && 87.5, 85.0 , 93.3 , 86.0 && 82.5 	, 82.5 , 78.9 , 79.6],
[85.0 , 91.7 , 86.7 , 88.0 && 97.5, 95.0 , 100  , 96.7 && 80.0	, 79.2 , 72.9 , 73.9],
[87.5 , 88.3 , 93.3 , 89.3 && 85.0, 96.7 , 85.0 , 88.7 && 75.0 	, 70.4 , 66.0 , 66.8],
[85.0 , 81.7 , 94.2 , 85.2 && 80.0, 96.7 , 81.7 , 86.5 && 67.5 	, 65.0 , 57.8 , 58.9],
[97.5 , 100  , 96.7 , 98.0 && 87.5, 97.5 , 90.0 , 92.9 && 75.0 	, 72.5 , 65.7 , 66.4],
[85.0 , 90.0 , 86.7 , 85.3 && 82.5, 96.7 , 84.2 , 89.5 && 60.0	, 52.9 , 44.4 , 46.8],
[90.0 , 85.0 , 95.0 , 88.3 && 85.0, 95.0 , 83.3 , 87.7 && 67.5 	, 65.4 , 55.6 , 58.2],
[87.5 , 90.0 , 93.3 , 89.0 && 85.0, 95.0 , 85.0 , 87.8 && 87.5 	, 83.3 , 79.4 , 80.9],
[92.5 , 95.0 , 91.7 , 93.0 && 87.5, 100  , 87.5 , 92.9 && 85.0	, 81.7 , 75.6 , 77.3],
[85.0 , 90.0 , 85.0 , 85.7 && 90.0, 100  , 89.2 , 93.7 && 77.5 	, 76.7 , 70.0 , 71.5],
[90.0 , 96.7 , 90.8 , 92.6 && 82.5, 77.5 , 89.2 , 80.5 && 87.5 	, 85.8 , 81.2 , 82.8],
[90.0 , 96.7 , 92.5 , 93.7 && 87.5, 96.7 , 87.5 , 91.2 && 80.0  , 66.7 , 56.1 , 60.3],
[92.5 , 96.7 , 94.2 , 94.6 && 87.5, 95.0 , 85.0 , 87.3 && 75.0 	, 72.5 , 64.4 , 67.1],
[97.5 , 100  , 96.7 , 98.0 && 85.0, 93.3 , 87.5 , 89.9 && 67.5 	, 60.8 , 49.6 , 53.6],
[97.5 , 100  , 96.7 , 98.0 && 92.5, 90.0 , 96.7 , 91.4 && 87.5 	, 85.0 , 79.7 , 81.6],
[85.0 , 90.0 , 87.5 , 85.9 && 90.0, 90.0 , 91.7 , 89.7 && 70.0	, 67.1 , 59.0 , 60.2],
[82.5 , 75.0 , 91.7 , 79.7 && 90.0, 100  , 88.3 , 92.7 && 67.5 	, 63.7 , 56.8 , 57.9]]

# %%
result = [[97.5 , 100  , 96.7 , 98.0 , 92.5, 96.7 , 94.2 , 94.6 , 72.5  , 70.8 , 60.0 , 62.9],
[87.5 , 85.0 , 93.3 , 86.0 , 87.5, 93.3 , 90.0 , 90.7 , 65.0  , 59.2 , 47.8 , 51.0],
[82.5 , 85.0 , 85.0 , 82.3 , 85.0, 95.0 , 81.7 , 86.0 , 75.0  , 69.6 , 64.3 , 65.4],
[85.0 , 80.0 , 91.7 , 83.0 , 87.5, 90.0 , 88.4 , 86.0 , 72.5 	, 63.7 , 53.7 , 57.3],
[92.5 , 91.7 , 96.7 , 92.7 , 82.5, 90.0 , 83.3 , 84.3 , 62.5 	, 60.0 , 48.7 , 52.1], 
[87.5 , 100  , 87.5 , 92.9 , 77.5, 77.5 , 82.5 , 77.8 , 67.5 	, 62.5 , 53.7 , 56.5],
[82.5 , 90.0 , 88.3 , 87.8 , 80.0, 88.3 , 83.3 , 83.1 , 70.0 	, 60.0 , 53.2 , 55.5],
[92.5 , 100  , 90.8 , 94.6 , 72.5, 84.2 , 73.3 , 76.7 , 62.5 	, 55.0 , 47.5 , 50.0],
[85.0 , 95.0 , 83.3 , 87.7 , 77.5, 85.0 , 83.3 , 82.0 , 62.5 	, 61.7 , 51.5 , 54.8],
[95.0 , 95.0 , 96.7 , 94.7 , 85.0, 86.7 , 90.8 , 85.9 , 85.0 	, 85.0 , 77.5 , 80.0],
[90.0 , 91.7 , 91.7 , 91.0 , 82.5, 85.0 , 81.7 , 81.3 , 67.5 	, 63.3 , 52.1 , 55.3],
[85.0 , 78.3 , 96.7 , 83.0 , 92.5, 100  , 92.5 , 95.7 , 82.5 	, 77.5 , 73.3 , 73.3],
[90.0 , 85.0 , 95.0 , 86.7 , 92.5, 100  , 92.5 , 95.7 , 72.5 	, 70.0 , 61.7 , 63.0],
[87.5 , 80.0 , 96.7 , 84.7 , 95.0, 96.7 , 96.7 , 96.0 , 62.5 	, 59.6 , 50.8 , 52.4],
[97.5 , 95.0 , 100  , 96.7 , 90.0, 85.0 , 95.0 , 88.3 , 67.5 	, 67.5 , 57.5 , 60.3],
[92.5 , 90.0 , 95.0 , 90.0 , 87.5, 85.0 , 93.3 , 86.0 , 82.5 	, 82.5 , 78.9 , 79.6],
[85.0 , 91.7 , 86.7 , 88.0 , 97.5, 95.0 , 100  , 96.7 , 80.0	, 79.2 , 72.9 , 73.9],
[87.5 , 88.3 , 93.3 , 89.3 , 85.0, 96.7 , 85.0 , 88.7 , 75.0 	, 70.4 , 66.0 , 66.8],
[85.0 , 81.7 , 94.2 , 85.2 , 80.0, 96.7 , 81.7 , 86.5 , 67.5 	, 65.0 , 57.8 , 58.9],
[97.5 , 100  , 96.7 , 98.0 , 87.5, 97.5 , 90.0 , 92.9 , 75.0 	, 72.5 , 65.7 , 66.4],
[85.0 , 90.0 , 86.7 , 85.3 , 82.5, 96.7 , 84.2 , 89.5 , 60.0	, 52.9 , 44.4 , 46.8],
[90.0 , 85.0 , 95.0 , 88.3 , 85.0, 95.0 , 83.3 , 87.7 , 67.5 	, 65.4 , 55.6 , 58.2],
[87.5 , 90.0 , 93.3 , 89.0 , 85.0, 95.0 , 85.0 , 87.8 , 87.5 	, 83.3 , 79.4 , 80.9],
[92.5 , 95.0 , 91.7 , 93.0 , 87.5, 100  , 87.5 , 92.9 , 85.0	, 81.7 , 75.6 , 77.3],
[85.0 , 90.0 , 85.0 , 85.7 , 90.0, 100  , 89.2 , 93.7 , 77.5 	, 76.7 , 70.0 , 71.5],
[90.0 , 96.7 , 90.8 , 92.6 , 82.5, 77.5 , 89.2 , 80.5 , 87.5 	, 85.8 , 81.2 , 82.8],
[90.0 , 96.7 , 92.5 , 93.7 , 87.5, 96.7 , 87.5 , 91.2 , 80.0  , 66.7 , 56.1 , 60.3],
[92.5 , 96.7 , 94.2 , 94.6 , 87.5, 95.0 , 85.0 , 87.3 , 75.0 	, 72.5 , 64.4 , 67.1],
[97.5 , 100  , 96.7 , 98.0 , 85.0, 93.3 , 87.5 , 89.9 , 67.5 	, 60.8 , 49.6 , 53.6],
[97.5 , 100  , 96.7 , 98.0 , 92.5, 90.0 , 96.7 , 91.4 , 87.5 	, 85.0 , 79.7 , 81.6],
[85.0 , 90.0 , 87.5 , 85.9 , 90.0, 90.0 , 91.7 , 89.7 , 70.0	, 67.1 , 59.0 , 60.2],
[82.5 , 75.0 , 91.7 , 79.7 , 90.0, 100  , 88.3 , 92.7 , 67.5 	, 63.7 , 56.8 , 57.9]]

# %%
np.mean(result, axis = 0)
# Out:
# array([89.375   , 90.890625, 92.43125 , 89.878125, 86.328125, 92.296875,
#        87.946875, 88.4125  , 73.125   , 69.26875 , 61.45    , 63.55    ])

# %%
np.std(result, axis = 0)
# Out:
# array([ 4.75985819,  6.96335764,  4.19846977,  5.08759118,  5.33943082,
#         6.28358399,  5.53381561,  5.1939117 ,  8.17293552,  9.18519316,
#        10.88588536, 10.31424985])
